# %%
import openpyxl
import pandas as pd
import numpy as np
from numpy.linalg import norm

feature_names = ['Age',	'Sex',	'ALB',	'ALP',	'ALT',	'AST',	'BIL',	'CHE',	'CHOL',	'CREA',	'GGT',	'PROT']
feature_names2 = ['Age',	'Sex',	'ALB',	'ALP',	'ALT',	'AST',	'BIL',	'CHE',	'CHOL',	'CREA',	'GGT',	'PROT',
                 'Age',	'Sex',	'ALB',	'ALP',	'ALT',	'AST',	'BIL',	'CHE',	'CHOL',	'CREA',	'GGT',	'PROT']
noOfIterations = 100

def convertSign(value):
    if value == "positive":
        return 1
    elif value == "negative":
        return 0
    else:
        return -1

def generateSignsRankings(feature_names):
    dataframe = openpyxl.load_workbook("outputHepatitisKernelShapLOOCV_1.xlsx")
    sheet = dataframe.active
   
    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_KernelShapRankings = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 7
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                list[k].append(row[4].value)
            else:
                list[k].append(row[step].value)
                step = step + 3
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_KernelShapRankings = pd.DataFrame(dict)
    
    for i in range(len(df_KernelShapRankings)):
        list = []
        for j in range(len(feature_names)):
            count = 0
            for k in range(len(feature_names)):
               if df_KernelShapRankings.iloc[i, k] > df_KernelShapRankings.iloc[i, j]:
                    count = count + 1
            count = count + 1
            list.append(count)
        df_KernelShapRankings.loc[i] = list

    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_KernelShapSigns = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 6
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                list[k].append(convertSign(row[3].value))
            else:
                list[k].append(convertSign(row[step].value))
                step = step + 3
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_KernelShapSigns = pd.DataFrame(dict)
  
    df_KernelShap = pd.concat([df_KernelShapRankings, df_KernelShapSigns], axis = 1)
    
    df_KernelShap.to_excel("signs_rankingsHepatitisKernelShap.xlsx")
   
    #################################################################
    dataframe = openpyxl.load_workbook("outputHepatitisTreeShapLOOCV_1.xlsx")
    sheet = dataframe.active
   
    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_TreeShapRankings = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 7
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                list[k].append(row[4].value)
            else:
                list[k].append(row[step].value)
                step = step + 3          
          
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_TreeShapRankings = pd.DataFrame(dict)
   
    for i in range(len(df_TreeShapRankings)):
        list = []
        for j in range(len(feature_names)):
            count = 0
            for k in range(len(feature_names)):
               if df_TreeShapRankings.iloc[i, k] > df_TreeShapRankings.iloc[i, j]:
                    count = count + 1
            count = count + 1
            list.append(count)
        df_TreeShapRankings.loc[i] = list


    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_TreeShapSigns = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 6
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                list[k].append(convertSign(row[3].value))
            else:
                list[k].append(convertSign(row[step].value))
                step = step + 3          
          
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_TreeShapSigns = pd.DataFrame(dict)

    df_TreeShap = pd.concat([df_TreeShapRankings, df_TreeShapSigns], axis = 1)

    df_TreeShap.to_excel("signs_rankingsHepatitisTreeShap.xlsx")    

    # ############################################################################
    dataframe = openpyxl.load_workbook("outputHepatitisLIMELOOCV_100.xlsx")
    sheet = dataframe.active
    
    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_LIMERankings = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 11
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                list[k].append(row[6].value)
            else:
                list[k].append(row[step].value)
                step = step + 5            
            
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_LIMERankings = pd.DataFrame(dict)
   
    for i in range(len(df_LIMERankings)):
        list = []
        for j in range(len(feature_names)):
            count = 0
            for k in range(len(feature_names)):
               if df_LIMERankings.iloc[i, k] > df_LIMERankings.iloc[i, j]:
                    count = count + 1
            count = count + 1
            list.append(count)
        df_LIMERankings.loc[i] = list


    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_LIMESigns = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 10
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                list[k].append(convertSign(row[5].value))
            else:
                list[k].append(convertSign(row[step].value))
                step = step + 5            
            
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_LIMESigns = pd.DataFrame(dict)
    df_LIME = pd.concat([df_LIMERankings, df_LIMESigns], axis = 1)

    df_LIME.to_excel("signs_rankingsHepatitisLIME.xlsx")
    ################################################################
    

def stackRowsColumns(M, noOfRows, noOfColumns):
    pos = [0] * noOfRows
    for i in range (0, noOfRows):
        pos[i] = i
    
    for i in range(1, noOfRows):
        wsim = [0] * noOfRows
        for j in range(i, noOfRows):
            for k in range(0, i):
                A = M.loc[k]
                B = M.loc[j]
                wsim[j] = wsim[j] + (1 / ( i - k)) * np.dot(A,B)/(norm(A)*norm(B))
        max_value = max(wsim)
        max_index = wsim.index(max_value)
        aux = M.loc[max_index]
        M.loc[max_index] = M.loc[i]
        M.loc[i] = aux
        aux = pos[max_index]
        pos[max_index] = pos[i]
        pos[i] = aux

    
    # for i in range(1, noOfColumns):
    #     wsim = [0] * noOfColumns
    #     for j in range(i, noOfColumns):
    #         for k in range(0, i):
    #             A = M.loc[k]
    #             B = M.loc[j]
    #             wsim[j] = wsim[j] + (1 / ( i - k)) * np.dot(A,B)/(norm(A)*norm(B))
    #     max_value = max(wsim)
    #     max_index = wsim.index(max_value)
    #     aux = M.loc[max_index]
    #     M.loc[max_index] = M.loc[i]
    #     M.loc[i] = aux
    return pos, M

def cosineSimilarity(A, B):
    return np.dot(A,B)/(norm(A)*norm(B))

def similarityCase(M, i):
    s = 0
    k = i - 1
    for j in range (1, k + 1):
        s = s + cosineSimilarity(M.loc[i], M.loc[i - j]) * (1 / j)
    return s

def similarityMatrix(M, noOfRows):
    s = 0
    for i in range(1, noOfRows):
        s = s + similarityCase(M, i)
    s = s / (noOfRows - 1)
    return s

def GlobalAlign(MSP, MS, noOfRows):
    if similarityMatrix(MSP, noOfRows) >  similarityMatrix(MS, noOfRows):
        max = similarityMatrix(MSP, noOfRows)
        min = similarityMatrix(MS, noOfRows)
    else:
        max = similarityMatrix(MS, noOfRows)
        min = similarityMatrix(MSP, noOfRows)
    return min / max
    #return similarityMatrix(MSP, noOfRows) / similarityMatrix(MS, noOfRows)


def createMSP(MP, MS, noOfRows):
    MS_copy = MS.copy(deep = True)
    MP_copy = MP.copy(deep = True)
    posS, MS_copy = stackRowsColumns(MS_copy, noOfRows, 2 * len(feature_names))
    posP, MP_copy = stackRowsColumns(MP_copy, noOfRows, 2 * len(feature_names))
    # MSP = pd.DataFrame(columns = feature_names2)
    # for i in range(0, noOfRows):
    #     MSP.loc[posP[i]] = MS_copy.loc[posS[i]]
    return GlobalAlign(MP_copy, MS_copy, noOfRows)

generateSignsRankings(feature_names)
df_KernelShap = pd.read_excel('signs_rankingsHepatitisKernelShap.xlsx')
df_KernelShap = df_KernelShap[df_KernelShap.columns[1:]]
df_TreeShap = pd.read_excel('signs_rankingsHepatitisTreeShap.xlsx')
df_TreeShap = df_TreeShap[df_TreeShap.columns[1:]]
df_LIME = pd.read_excel('signs_rankingsHepatitisLIME.xlsx')
df_LIME = df_LIME[df_LIME.columns[1:]]


results = pd.DataFrame(columns = ['LL', 'LS', 'SL', 'SS'])
noOfInstances = df_KernelShap.shape[0]
for instance in range(0, noOfInstances):
    print(instance)
    result = []
    data_Shap = []
    for i in range(int(noOfIterations / 2)):
        data_Shap.append(df_KernelShap.loc[instance].values.flatten().tolist())
        data_Shap.append(df_TreeShap.loc[instance].values.flatten().tolist())
    M_Shap  = pd.DataFrame(data_Shap, columns = feature_names2)
    
    data_LIME = []
    for i in range(noOfIterations):
        data_LIME.append(df_LIME.loc[instance * noOfIterations + i].values.flatten().tolist())
    M_LIME  = pd.DataFrame(data_LIME, columns = feature_names2)
    
    MP = M_LIME
    MS = M_LIME
    result.append(createMSP(MP, MS, noOfIterations))
    MP = M_LIME
    MS = M_Shap
    result.append(createMSP(MP, MS, noOfIterations))
    MP = M_Shap
    MS = M_LIME
    result.append(createMSP(MP, MS, noOfIterations))
    MP = M_Shap
    MS = M_Shap
    result.append(createMSP(MP, MS, noOfIterations))
    print(result)
    results.loc[instance] = result


results.to_excel("resultsSignsRankingsHepatitisMPMS_MinMax.xlsx")
# Out:
# 0
# [1.0, 0.8545111924484731, 0.8545111924484731, 1.0]
# 1
# [1.0, 0.8705345787866596, 0.8705345787866596, 1.0]
# 2
# [1.0, 0.8646988697251556, 0.8646988697251556, 1.0]
# 3
# [1.0, 0.8645232113825945, 0.8645232113825945, 1.0]
# 4
# [1.0, 0.8512100810002522, 0.8512100810002522, 1.0]
# 5
# [1.0, 0.8963336033376538, 0.8963336033376538, 1.0]
# 6
# [1.0, 0.8613419680424202, 0.8613419680424202, 1.0]
# 7
# [1.0, 0.860592899936528, 0.860592899936528, 1.0]
# 8
# [1.0, 0.8704781844703703, 0.8704781844703703, 1.0]
# 9
# [1.0, 0.8474383583240707, 0.8474383583240707, 1.0]
# 10
# [1.0, 0.862762270162266, 0.862762270162266, 1.0]
# 11
# [1.0, 0.8423000982638805, 0.8423000982638805, 1.0]
# 12
# [1.0, 0.8473833648888186, 0.8473833648888186, 1.0]
# 13
# [1.0, 0.8730557883455958, 0.8730557883455958, 1.0]
# 14
# [1.0, 0.850420549392361, 0.850420549392361, 1.0]
# 15
# [1.0, 0.862872263070769, 0.862872263070769, 1.0]
# 16
# [1.0, 0.8728146471197197, 0.8728146471197197, 1.0]
# 17
# [1.0, 0.8734735321110004, 0.8734735321110004, 1.0]
# 18
# [1.0, 0.8552182806459466, 0.8552182806459466, 1.0]
# 19
# [1.0, 0.885891624020024, 0.885891624020024, 1.0]
# 20
# [1.0, 0.8784928583590715, 0.8784928583590715, 1.0]
# 21
# [1.0, 0.8486359636049297, 0.8486359636049297, 1.0]
# 22
# [1.0, 0.8623926362444716, 0.8623926362444716, 1.0]
# 23
# [1.0, 0.8829734084194689, 0.8829734084194689, 1.0]
# 24
# [1.0, 0.8507758986212289, 0.8507758986212289, 1.0]
# 25
# [1.0, 0.8506757567329853, 0.8506757567329853, 1.0]
# 26
# [1.0, 0.8695901383721637, 0.8695901383721637, 1.0]
# 27
# [1.0, 0.849910830400423, 0.849910830400423, 1.0]
# 28
# [1.0, 0.8705718743106674, 0.8705718743106674, 1.0]
# 29
# [1.0, 0.8605370627767467, 0.8605370627767467, 1.0]
# 30
# [1.0, 0.8847514184139234, 0.8847514184139234, 1.0]
# 31
# [1.0, 0.8517820141678271, 0.8517820141678271, 1.0]
# 32
# [1.0, 0.8446654343420364, 0.8446654343420364, 1.0]
# 33
# [1.0, 0.8469806719719305, 0.8469806719719305, 1.0]
# 34
# [1.0, 0.8482416295786364, 0.8482416295786364, 1.0]
# 35
# [1.0, 0.8551082726021159, 0.8551082726021159, 1.0]
# 36
# [1.0, 0.8592282619118529, 0.8592282619118529, 1.0]
# 37
# [1.0, 0.8516859811773507, 0.8516859811773507, 1.0]
# 38
# [1.0, 0.8611618339111234, 0.8611618339111234, 1.0]
# 39
# [1.0, 0.8590527217105164, 0.8590527217105164, 1.0]
# 40
# [1.0, 0.9011020188636051, 0.9011020188636051, 1.0]
# 41
# [1.0, 0.8572300918056588, 0.8572300918056588, 1.0]
# 42
# [1.0, 0.8607481401449165, 0.8607481401449165, 1.0]
# 43
# [1.0, 0.8433696204435396, 0.8433696204435396, 1.0]
# 44
# [1.0, 0.8636362367179343, 0.8636362367179343, 1.0]
# [1.0, 0.8455168562620471, 0.8455168562620471, 1.0]
# 396
# [1.0, 0.8604571692685635, 0.8604571692685635, 1.0]
# 397
# [1.0, 0.8511754119407562, 0.8511754119407562, 1.0]
# 398
# [1.0, 0.8744743839516413, 0.8744743839516413, 1.0]
# 399
# [1.0, 0.8605088477442909, 0.8605088477442909, 1.0]
# 400
# [1.0, 0.8571232969922036, 0.8571232969922036, 1.0]
# 401
# [1.0, 0.8546317061933424, 0.8546317061933424, 1.0]
# 402
# [1.0, 0.8770369225936896, 0.8770369225936896, 1.0]
# 403
# [1.0, 0.8639824045467949, 0.8639824045467949, 1.0]
# 404
# [1.0, 0.8560409296224605, 0.8560409296224605, 1.0]
# 405
# [1.0, 0.8420719945106632, 0.8420719945106632, 1.0]
# 406
# [1.0, 0.8529132914896326, 0.8529132914896326, 1.0]
# 407
# [1.0, 0.856615428939983, 0.856615428939983, 1.0]
# 408
# [1.0, 0.8714482029635982, 0.8714482029635982, 1.0]
# 409
# [1.0, 0.857562343319761, 0.857562343319761, 1.0]
# 410
# [1.0, 0.8734744164686326, 0.8734744164686326, 1.0]
# 411
# [1.0, 0.8697518566979544, 0.8697518566979544, 1.0]
# 412
# [1.0, 0.8593061535728492, 0.8593061535728492, 1.0]
# 413
# [1.0, 0.8961684599242818, 0.8961684599242818, 1.0]
# 414
# [1.0, 0.8440141303714032, 0.8440141303714032, 1.0]
# 415
# [1.0, 0.8698046211459395, 0.8698046211459395, 1.0]
# 416
# [1.0, 0.8583268920608611, 0.8583268920608611, 1.0]
# 417
# [1.0, 0.8578358114596727, 0.8578358114596727, 1.0]
# 418
# [1.0, 0.8704169454122088, 0.8704169454122088, 1.0]
# 419
# [1.0, 0.8618847319786247, 0.8618847319786247, 1.0]
# 420
# [1.0, 0.8548487308581422, 0.8548487308581422, 1.0]
# 421
# [1.0, 0.8440607379402433, 0.8440607379402433, 1.0]
# 422
# [1.0, 0.8490650917007171, 0.8490650917007171, 1.0]
# 423
# [1.0, 0.8470629132891406, 0.8470629132891406, 1.0]
# 424
# [1.0, 0.8713750154314769, 0.8713750154314769, 1.0]
# 425
# [1.0, 0.8607552845612253, 0.8607552845612253, 1.0]
# 426
# [1.0, 0.8618533372760518, 0.8618533372760518, 1.0]
# 427
# [1.0, 0.846520647202884, 0.846520647202884, 1.0]
# 428
# [1.0, 0.8674919348692818, 0.8674919348692818, 1.0]
# 429
# [1.0, 0.8622919787859111, 0.8622919787859111, 1.0]
# 430
# [1.0, 0.8477942921219742, 0.8477942921219742, 1.0]
# 431
# [1.0, 0.8566904801643331, 0.8566904801643331, 1.0]
# 432
# [1.0, 0.8740701257378313, 0.8740701257378313, 1.0]
# 433
# [1.0, 0.8543325184263054, 0.8543325184263054, 1.0]
# 434
# [1.0, 0.8467958098148225, 0.8467958098148225, 1.0]
# 435
# [1.0, 0.876157888441089, 0.876157888441089, 1.0]
# 436
# [1.0, 0.8542467142398518, 0.8542467142398518, 1.0]
# 437
# [1.0, 0.8563333194454921, 0.8563333194454921, 1.0]
# 438
# [1.0, 0.8591285387994044, 0.8591285387994044, 1.0]
# 439
# [1.0, 0.8463218609704072, 0.8463218609704072, 1.0]
# 440
# [1.0, 0.8553415553843363, 0.8553415553843363, 1.0]
# 441
# [1.0, 0.8622103183952268, 0.8622103183952268, 1.0]
# 442
# [1.0, 0.8555530198667353, 0.8555530198667353, 1.0]
# 443
# [1.0, 0.8420280205237592, 0.8420280205237592, 1.0]
# 444
# [1.0, 0.859766264810491, 0.859766264810491, 1.0]
# 445
# [1.0, 0.8449961099516805, 0.8449961099516805, 1.0]
# 446
# [1.0, 0.8521610139710282, 0.8521610139710282, 1.0]
# 447
# [1.0, 0.8450356012662985, 0.8450356012662985, 1.0]
# 448
# [1.0, 0.8551928106805107, 0.8551928106805107, 1.0]
# 449
# [1.0, 0.864992361168244, 0.864992361168244, 1.0]
# 450
# [1.0, 0.8552718955415517, 0.8552718955415517, 1.0]
# 451
# [1.0, 0.848493760390015, 0.848493760390015, 1.0]
# 452
# [1.0, 0.8584044442708667, 0.8584044442708667, 1.0]
# 453
# [1.0, 0.8550226107834209, 0.8550226107834209, 1.0]
# 454
# [1.0, 0.8467600136010527, 0.8467600136010527, 1.0]
# 455
# [1.0, 0.8550780756447364, 0.8550780756447364, 1.0]
# 456
# [1.0, 0.8449257179511336, 0.8449257179511336, 1.0]
# 457
# [1.0, 0.8556177634723701, 0.8556177634723701, 1.0]
# 458
# [1.0, 0.8496512648318735, 0.8496512648318735, 1.0]
# 459
# [1.0, 0.8781151431111969, 0.8781151431111969, 1.0]
# 460
# [1.0, 0.8532482493403327, 0.8532482493403327, 1.0]
# 461
# [1.0, 0.8696322053659965, 0.8696322053659965, 1.0]
# 462
# [1.0, 0.8550515537640742, 0.8550515537640742, 1.0]
# 463
# [1.0, 0.8572089015465837, 0.8572089015465837, 1.0]
# 464
# [1.0, 0.8647304386462972, 0.8647304386462972, 1.0]
# 465
# [1.0, 0.8815606621351931, 0.8815606621351931, 1.0]
# 466
# [1.0, 0.9031522504379836, 0.9031522504379836, 1.0]
# 467
# [1.0, 0.8562412688746381, 0.8562412688746381, 1.0]
# 468
# [1.0, 0.8671988224319929, 0.8671988224319929, 1.0]
# 469
# [1.0, 0.8466851424364865, 0.8466851424364865, 1.0]
# 470
# [1.0, 0.8509519121457264, 0.8509519121457264, 1.0]
# 471
# [1.0, 0.8563502922651054, 0.8563502922651054, 1.0]
# 472
# [1.0, 0.8707035738812655, 0.8707035738812655, 1.0]
# 473
# [1.0, 0.8679333948374515, 0.8679333948374515, 1.0]
# 474
# [1.0, 0.8509138179240007, 0.8509138179240007, 1.0]
# 475
# [1.0, 0.8632968604949498, 0.8632968604949498, 1.0]
# 476
# [1.0, 0.848564576388551, 0.848564576388551, 1.0]
# 477
# [1.0, 0.8475731858371622, 0.8475731858371622, 1.0]
# 478
# [1.0, 0.8580728915200073, 0.8580728915200073, 1.0]
# 479
# [1.0, 0.8440107694989777, 0.8440107694989777, 1.0]
# 480
# [1.0, 0.8444492262812936, 0.8444492262812936, 1.0]
# 481
# [1.0, 0.8752598860497676, 0.8752598860497676, 1.0]
# 482
# [1.0, 0.8530971684098335, 0.8530971684098335, 1.0]
# 483
# [1.0, 0.8442658387765285, 0.8442658387765285, 1.0]
# 484
# [1.0, 0.8491744371534474, 0.8491744371534474, 1.0]
# 485
# [1.0, 0.8674492164741706, 0.8674492164741706, 1.0]
# 486
# [1.0, 0.8606485576995104, 0.8606485576995104, 1.0]
# 487
# [1.0, 0.8622948325214645, 0.8622948325214645, 1.0]
# 488
# [1.0, 0.8555763372629135, 0.8555763372629135, 1.0]
# 489
# [1.0, 0.846108798164299, 0.846108798164299, 1.0]
# 490
# [1.0, 0.869136772967193, 0.869136772967193, 1.0]
# 491
# [1.0, 0.8567667945742784, 0.8567667945742784, 1.0]
# 492
# [1.0, 0.8623483174431332, 0.8623483174431332, 1.0]
# 493
# [1.0, 0.8547522595288469, 0.8547522595288469, 1.0]
# 494
# [1.0, 0.8475696506945499, 0.8475696506945499, 1.0]
# 495
# [1.0, 0.8655671822000525, 0.8655671822000525, 1.0]
# 496
# [1.0, 0.8479451141870809, 0.8479451141870809, 1.0]
# 497
# [1.0, 0.8503911320042157, 0.8503911320042157, 1.0]
# 498
# [1.0, 0.8485308304347028, 0.8485308304347028, 1.0]
# 499
# [1.0, 0.8584215382424185, 0.8584215382424185, 1.0]
# 500
# [1.0, 0.8694837380838122, 0.8694837380838122, 1.0]
# 501
# [1.0, 0.8519505531079099, 0.8519505531079099, 1.0]
# 502
# [1.0, 0.858248991661763, 0.858248991661763, 1.0]
# 503
# [1.0, 0.8530828150024087, 0.8530828150024087, 1.0]
# 504
# [1.0, 0.8363240987352013, 0.8363240987352013, 1.0]
# 505
# [1.0, 0.8740734400962937, 0.8740734400962937, 1.0]
# 506
# [1.0, 0.8616748818331083, 0.8616748818331083, 1.0]
# 507
# [1.0, 0.8525693474511685, 0.8525693474511685, 1.0]
# 508
# [1.0, 0.8543236331724265, 0.8543236331724265, 1.0]
# 509
# [1.0, 0.8925527432220873, 0.8925527432220873, 1.0]
# 510
# [1.0, 0.863601567399239, 0.863601567399239, 1.0]
# 511
# [1.0, 0.8421222578517547, 0.8421222578517547, 1.0]
# 512
# [1.0, 0.8450750859369215, 0.8450750859369215, 1.0]
# 513
# [1.0, 0.8532131308718754, 0.8532131308718754, 1.0]
# 514
# [1.0, 0.8524450115381702, 0.8524450115381702, 1.0]
# 515
# [1.0, 0.8575690647636542, 0.8575690647636542, 1.0]
# 516
# [1.0, 0.8595592867998703, 0.8595592867998703, 1.0]
# 517
# [1.0, 0.842051575545755, 0.842051575545755, 1.0]
# 518
# [1.0, 0.8513120444749847, 0.8513120444749847, 1.0]
# 519
# [1.0, 0.8807396863231216, 0.8807396863231216, 1.0]
# 520
# [1.0, 0.852521378659576, 0.852521378659576, 1.0]
# 521
# [1.0, 0.8466326360310108, 0.8466326360310108, 1.0]
# 522
# [1.0, 0.8454505142222998, 0.8454505142222998, 1.0]
# 523
# [1.0, 0.843353735880348, 0.843353735880348, 1.0]
# 524
# [1.0, 0.8688305673587827, 0.8688305673587827, 1.0]
# 525
# [1.0, 0.846488288392673, 0.846488288392673, 1.0]
# 526
# [1.0, 0.8553009404884957, 0.8553009404884957, 1.0]
# 527
# [1.0, 0.8732393514720774, 0.8732393514720774, 1.0]
# 528
# [1.0, 0.8479901265066494, 0.8479901265066494, 1.0]
# 529
# [1.0, 0.8596133173519102, 0.8596133173519102, 1.0]
# 530
# [1.0, 0.8590168832821341, 0.8590168832821341, 1.0]
# 531
# [1.0, 0.8548505713935246, 0.8548505713935246, 1.0]
# 532
# [1.0, 0.8539543099582149, 0.8539543099582149, 1.0]
# 533
# [1.0, 0.8733832981416787, 0.8733832981416787, 1.0]
# 534
# [1.0, 0.8536730150192523, 0.8536730150192523, 1.0]
# 535
# [1.0, 0.8766916083064203, 0.8766916083064203, 1.0]
# 536
# [1.0, 0.8496367239349512, 0.8496367239349512, 1.0]
# 537
# [1.0, 0.8745588093775802, 0.8745588093775802, 1.0]
# 538
# [1.0, 0.9109975013979726, 0.9109975013979726, 1.0]
# 539
# [1.0, 0.8705451690092874, 0.8705451690092874, 1.0]
# 540
# [1.0, 0.8573452384259785, 0.8573452384259785, 1.0]
# 541
# [1.0, 0.8809800680597142, 0.8809800680597142, 1.0]
# 542
# [1.0, 0.8562829551032404, 0.8562829551032404, 1.0]
# 543
# [1.0, 0.869926979075308, 0.869926979075308, 1.0]
# 544
# [1.0, 0.8591975361400926, 0.8591975361400926, 1.0]
# 545
# [1.0, 0.8659513320528394, 0.8659513320528394, 1.0]
# 546
# [1.0, 0.9155746574496995, 0.9155746574496995, 1.0]
# 547
# [1.0, 0.8601667462046323, 0.8601667462046323, 1.0]
# 548
# [1.0, 0.876345768497249, 0.876345768497249, 1.0]
# 549
# [1.0, 0.8713061985622599, 0.8713061985622599, 1.0]
# 550
# [1.0, 0.8523218569302727, 0.8523218569302727, 1.0]
# 551
# [1.0, 0.8711924765251846, 0.8711924765251846, 1.0]
# 552
# [1.0, 0.8657866114812219, 0.8657866114812219, 1.0]
# 553
# [1.0, 0.8641736628173499, 0.8641736628173499, 1.0]
# 554
# [1.0, 0.855277935566222, 0.855277935566222, 1.0]
# 555
# [1.0, 0.8740204177719635, 0.8740204177719635, 1.0]
# 556
# [1.0, 0.8699577783729638, 0.8699577783729638, 1.0]
# 557
# [1.0, 0.866354606357258, 0.866354606357258, 1.0]
# 558
# [1.0, 0.884829085675324, 0.884829085675324, 1.0]
# 559
# [1.0, 0.8885143971439828, 0.8885143971439828, 1.0]
# 560
# [1.0, 0.8566690264643424, 0.8566690264643424, 1.0]
# 561
# [1.0, 0.8606050761863233, 0.8606050761863233, 1.0]
# 562
# [1.0, 0.8717378230183636, 0.8717378230183636, 1.0]
# 563
# [1.0, 0.8647969794837066, 0.8647969794837066, 1.0]
# 564
# [1.0, 0.8833328726376559, 0.8833328726376559, 1.0]
# 565
# [1.0, 0.8734903102047653, 0.8734903102047653, 1.0]
# 566
# [1.0, 0.89122413728926, 0.89122413728926, 1.0]
# 567
# [1.0, 0.8869046219852856, 0.8869046219852856, 1.0]
# 568
# [1.0, 0.8538776706077419, 0.8538776706077419, 1.0]
# 569
# [1.0, 0.8729719364382529, 0.8729719364382529, 1.0]
# 570
# [1.0, 0.8903935197458941, 0.8903935197458941, 1.0]
# 571
# [1.0, 0.8901237890569935, 0.8901237890569935, 1.0]
# 572
# [1.0, 0.8652341559905845, 0.8652341559905845, 1.0]
# 573
# [1.0, 0.867138713146277, 0.867138713146277, 1.0]
# 574
# [1.0, 0.8594849783548608, 0.8594849783548608, 1.0]
# 575
# [1.0, 0.8564400542939062, 0.8564400542939062, 1.0]
# 576
# [1.0, 0.8575620743968081, 0.8575620743968081, 1.0]
# 577
# [1.0, 0.8696305204806907, 0.8696305204806907, 1.0]
# 578
# [1.0, 0.8718470534280789, 0.8718470534280789, 1.0]
# 579
# [1.0, 0.8748111363952151, 0.8748111363952151, 1.0]
# 580
# [1.0, 0.8510527207909506, 0.8510527207909506, 1.0]
# 581
# [1.0, 0.8669461469684031, 0.8669461469684031, 1.0]
# 582
# [1.0, 0.8615245682060184, 0.8615245682060184, 1.0]
# 583
# [1.0, 0.8757674055152234, 0.8757674055152234, 1.0]
# 584
# [1.0, 0.8628391517295811, 0.8628391517295811, 1.0]
# 585
# [1.0, 0.8661619527795232, 0.8661619527795232, 1.0]
# 586
# [1.0, 0.8727998700725202, 0.8727998700725202, 1.0]
# 587
# [1.0, 0.866980515778622, 0.866980515778622, 1.0]
# 588
# [1.0, 0.8763074578157246, 0.8763074578157246, 1.0]
# 589
# [1.0, 0.8648565354372314, 0.8648565354372314, 1.0]
# 590
# [1.0, 0.8553986708978051, 0.8553986708978051, 1.0]
# 591
# [1.0, 0.8669416596438163, 0.8669416596438163, 1.0]
# 592
# [1.0, 0.8711939325410928, 0.8711939325410928, 1.0]
# 593
# [1.0, 0.882597177669087, 0.882597177669087, 1.0]
# 594
# [1.0, 0.8900831315502103, 0.8900831315502103, 1.0]
# 595
# [1.0, 0.8664518335157578, 0.8664518335157578, 1.0]
# 596
# [1.0, 0.8630083102684527, 0.8630083102684527, 1.0]
# 597
# [1.0, 0.8650025685627254, 0.8650025685627254, 1.0]
# 598
# [1.0, 0.8616720851808471, 0.8616720851808471, 1.0]
# 599
# [1.0, 0.8641697449947044, 0.8641697449947044, 1.0]
# 600
# [1.0, 0.8730348483188607, 0.8730348483188607, 1.0]
# 601
# [1.0, 0.8622728447332132, 0.8622728447332132, 1.0]
# 602
# [1.0, 0.8932083832891835, 0.8932083832891835, 1.0]
# 603
# [1.0, 0.8571481838650968, 0.8571481838650968, 1.0]
# 604
# [1.0, 0.852796928664485, 0.852796928664485, 1.0]
# 605
# [1.0, 0.8624100256000402, 0.8624100256000402, 1.0]
# 606
# [1.0, 0.8974907384932657, 0.8974907384932657, 1.0]
# 607
# [1.0, 0.8673011898578963, 0.8673011898578963, 1.0]
# 608
# [1.0, 0.8848159392610363, 0.8848159392610363, 1.0]
# 609
# [1.0, 0.8405524133564409, 0.8405524133564409, 1.0]
# 610
# [1.0, 0.8663667266990518, 0.8663667266990518, 1.0]
# 611
# [1.0, 0.8643786059387463, 0.8643786059387463, 1.0]
# 612
# [1.0, 0.8616329921170154, 0.8616329921170154, 1.0]
# 613
# [1.0, 0.8645384243739139, 0.8645384243739139, 1.0]
# 614
# [1.0, 0.8588087736503884, 0.8588087736503884, 1.0]
