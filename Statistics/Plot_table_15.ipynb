# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv('data_table_15.csv')
sns.catplot(data=data, x="Dataset", y="Increase ROC-AUC score (%)", hue="Feature overlap method", kind="bar")
plt.tick_params(axis='both', which='major', labelsize=8)
