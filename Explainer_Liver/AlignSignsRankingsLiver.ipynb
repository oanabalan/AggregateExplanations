# %%
import openpyxl
import pandas as pd
import numpy as np
from numpy.linalg import norm

feature_names = ['Age', 'TB', 'DB', 'Alkphos', 'Sgpt','TP', 'ALB', 'AG_Ratio', 'Gender']
feature_names2 = ['Age', 'TB', 'DB', 'Alkphos', 'Sgpt','TP', 'ALB', 'AG_Ratio', 'Gender',
                 'Age', 'TB', 'DB', 'Alkphos', 'Sgpt','TP', 'ALB', 'AG_Ratio', 'Gender']
noOfIterations = 100

def convertSign(value):
    if value == "positive":
        return 1
    elif value == "negative":
        return 0
    else:
        return -1

def generateSignsRankings(feature_names):
    dataframe = openpyxl.load_workbook("outputLiverKernelShapLOOCV_1.xlsx")
    sheet = dataframe.active
   
    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_KernelShapRankings = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 7
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                list[k].append(row[4].value)
            else:
                list[k].append(row[step].value)
                step = step + 3
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_KernelShapRankings = pd.DataFrame(dict)
    
    for i in range(len(df_KernelShapRankings)):
        list = []
        for j in range(len(feature_names)):
            count = 0
            for k in range(len(feature_names)):
               if df_KernelShapRankings.iloc[i, k] > df_KernelShapRankings.iloc[i, j]:
                    count = count + 1
            count = count + 1
            list.append(count)
        df_KernelShapRankings.loc[i] = list

    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_KernelShapSigns = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 6
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                list[k].append(convertSign(row[3].value))
            else:
                list[k].append(convertSign(row[step].value))
                step = step + 3
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_KernelShapSigns = pd.DataFrame(dict)
  
    df_KernelShap = pd.concat([df_KernelShapRankings, df_KernelShapSigns], axis = 1)
    
    df_KernelShap.to_excel("signs_rankingsLiverKernelShap.xlsx")
   
    #################################################################
    dataframe = openpyxl.load_workbook("outputLiverTreeShapLOOCV_1.xlsx")
    sheet = dataframe.active
   
    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_TreeShapRankings = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 7
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                list[k].append(row[4].value)
            else:
                list[k].append(row[step].value)
                step = step + 3          
          
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_TreeShapRankings = pd.DataFrame(dict)
   
    for i in range(len(df_TreeShapRankings)):
        list = []
        for j in range(len(feature_names)):
            count = 0
            for k in range(len(feature_names)):
               if df_TreeShapRankings.iloc[i, k] > df_TreeShapRankings.iloc[i, j]:
                    count = count + 1
            count = count + 1
            list.append(count)
        df_TreeShapRankings.loc[i] = list


    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_TreeShapSigns = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 6
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                list[k].append(convertSign(row[3].value))
            else:
                list[k].append(convertSign(row[step].value))
                step = step + 3          
          
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_TreeShapSigns = pd.DataFrame(dict)

    df_TreeShap = pd.concat([df_TreeShapRankings, df_TreeShapSigns], axis = 1)

    df_TreeShap.to_excel("signs_rankingsLiverTreeShap.xlsx")    

    # ############################################################################
    dataframe = openpyxl.load_workbook("outputLiverLIMELOOCV_100.xlsx")
    sheet = dataframe.active
    
    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_LIMERankings = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 11
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                list[k].append(row[6].value)
            else:
                list[k].append(row[step].value)
                step = step + 5            
            
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_LIMERankings = pd.DataFrame(dict)
   
    for i in range(len(df_LIMERankings)):
        list = []
        for j in range(len(feature_names)):
            count = 0
            for k in range(len(feature_names)):
               if df_LIMERankings.iloc[i, k] > df_LIMERankings.iloc[i, j]:
                    count = count + 1
            count = count + 1
            list.append(count)
        df_LIMERankings.loc[i] = list


    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_LIMESigns = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 10
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                list[k].append(convertSign(row[5].value))
            else:
                list[k].append(convertSign(row[step].value))
                step = step + 5            
            
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_LIMESigns = pd.DataFrame(dict)
    df_LIME = pd.concat([df_LIMERankings, df_LIMESigns], axis = 1)

    df_LIME.to_excel("signs_rankingsLiverLIME.xlsx")
    ################################################################
    

def stackRowsColumns(M, noOfRows, noOfColumns):
    pos = [0] * noOfRows
    for i in range (0, noOfRows):
        pos[i] = i
    
    for i in range(1, noOfRows):
        wsim = [0] * noOfRows
        for j in range(i, noOfRows):
            for k in range(0, i):
                A = M.loc[k]
                B = M.loc[j]
                wsim[j] = wsim[j] + (1 / ( i - k)) * np.dot(A,B)/(norm(A)*norm(B))
        max_value = max(wsim)
        max_index = wsim.index(max_value)
        aux = M.loc[max_index]
        M.loc[max_index] = M.loc[i]
        M.loc[i] = aux
        aux = pos[max_index]
        pos[max_index] = pos[i]
        pos[i] = aux

    
    # for i in range(1, noOfColumns):
    #     wsim = [0] * noOfColumns
    #     for j in range(i, noOfColumns):
    #         for k in range(0, i):
    #             A = M.loc[k]
    #             B = M.loc[j]
    #             wsim[j] = wsim[j] + (1 / ( i - k)) * np.dot(A,B)/(norm(A)*norm(B))
    #     max_value = max(wsim)
    #     max_index = wsim.index(max_value)
    #     aux = M.loc[max_index]
    #     M.loc[max_index] = M.loc[i]
    #     M.loc[i] = aux
    return pos, M

def cosineSimilarity(A, B):
    return np.dot(A,B)/(norm(A)*norm(B))

def similarityCase(M, i):
    s = 0
    k = i - 1
    for j in range (1, k + 1):
        s = s + cosineSimilarity(M.loc[i], M.loc[i - j]) * (1 / j)
    return s

def similarityMatrix(M, noOfRows):
    s = 0
    for i in range(1, noOfRows):
        s = s + similarityCase(M, i)
    s = s / (noOfRows - 1)
    return s

def GlobalAlign(MSP, MS, noOfRows):
    if similarityMatrix(MSP, noOfRows) >  similarityMatrix(MS, noOfRows):
        max = similarityMatrix(MSP, noOfRows)
        min = similarityMatrix(MS, noOfRows)
    else:
        max = similarityMatrix(MS, noOfRows)
        min = similarityMatrix(MSP, noOfRows)
    return min / max
    #return similarityMatrix(MSP, noOfRows) / similarityMatrix(MS, noOfRows)


def createMSP(MP, MS, noOfRows):
    MS_copy = MS.copy(deep = True)
    MP_copy = MP.copy(deep = True)
    posS, MS_copy = stackRowsColumns(MS_copy, noOfRows, 2 * len(feature_names))
    posP, MP_copy = stackRowsColumns(MP_copy, noOfRows, 2 * len(feature_names))
    # MSP = pd.DataFrame(columns = feature_names2)
    # for i in range(0, noOfRows):
    #     MSP.loc[posP[i]] = MS_copy.loc[posS[i]]
    return GlobalAlign(MP_copy, MS_copy, noOfRows)

generateSignsRankings(feature_names)
df_KernelShap = pd.read_excel('signs_rankingsLiverKernelShap.xlsx')
df_KernelShap = df_KernelShap[df_KernelShap.columns[1:]]
df_TreeShap = pd.read_excel('signs_rankingsLiverTreeShap.xlsx')
df_TreeShap = df_TreeShap[df_TreeShap.columns[1:]]
df_LIME = pd.read_excel('signs_rankingsLiverLIME.xlsx')
df_LIME = df_LIME[df_LIME.columns[1:]]


results = pd.DataFrame(columns = ['LL', 'LS', 'SL', 'SS'])
noOfInstances = df_KernelShap.shape[0]
for instance in range(0, noOfInstances):
    print(instance)
    result = []
    data_Shap = []
    for i in range(int(noOfIterations / 2)):
        data_Shap.append(df_KernelShap.loc[instance].values.flatten().tolist())
        data_Shap.append(df_TreeShap.loc[instance].values.flatten().tolist())
    M_Shap  = pd.DataFrame(data_Shap, columns = feature_names2)
    
    data_LIME = []
    for i in range(noOfIterations):
        data_LIME.append(df_LIME.loc[instance * noOfIterations + i].values.flatten().tolist())
    M_LIME  = pd.DataFrame(data_LIME, columns = feature_names2)
    
    MP = M_LIME
    MS = M_LIME
    result.append(createMSP(MP, MS, noOfIterations))
    MP = M_LIME
    MS = M_Shap
    result.append(createMSP(MP, MS, noOfIterations))
    MP = M_Shap
    MS = M_LIME
    result.append(createMSP(MP, MS, noOfIterations))
    MP = M_Shap
    MS = M_Shap
    result.append(createMSP(MP, MS, noOfIterations))
    print(result)
    results.loc[instance] = result


results.to_excel("resultsSignsRankingsLiverMPMS_MinMax.xlsx")
# Out:
# 0
# [1.0, 0.969553667968635, 0.969553667968635, 1.0]
# 1
# [1.0, 0.9143253238450987, 0.9143253238450987, 1.0]
# 2
# [1.0, 0.976772797900251, 0.976772797900251, 1.0]
# 3
# [1.0, 0.9732837146878233, 0.9732837146878233, 1.0]
# 4
# [1.0, 0.8514034674021904, 0.8514034674021904, 1.0]
# 5
# [1.0, 0.9347349962130687, 0.9347349962130687, 1.0]
# 6
# [1.0, 0.9430680742451142, 0.9430680742451142, 1.0]
# 7
# [1.0, 0.9966116416811369, 0.9966116416811369, 1.0]
# 8
# [1.0, 0.9394735683106162, 0.9394735683106162, 1.0]
# 9
# [1.0, 0.955798474861152, 0.955798474861152, 1.0]
# 10
# [1.0, 0.908807097701277, 0.908807097701277, 1.0]
# 11
# [1.0, 0.9138835503666386, 0.9138835503666386, 1.0]
# 12
# [1.0, 0.9605643012348747, 0.9605643012348747, 1.0]
# 13
# [1.0, 0.9687069883514845, 0.9687069883514845, 1.0]
# 14
# [1.0, 0.9777525400751942, 0.9777525400751942, 1.0]
# 15
# [1.0, 0.9855726048216233, 0.9855726048216233, 1.0]
# 16
# [1.0, 0.9847436381423971, 0.9847436381423971, 1.0]
# 17
# [1.0, 0.9977166985549007, 0.9977166985549007, 1.0]
# 18
# [1.0, 0.9679321236089262, 0.9679321236089262, 1.0]
# 19
# [1.0, 0.9719694030463486, 0.9719694030463486, 1.0]
# 20
# [1.0, 0.9593975139397043, 0.9593975139397043, 1.0]
# 21
# [1.0, 0.9156148478616952, 0.9156148478616952, 1.0]
# 22
# [1.0, 0.9373852883319571, 0.9373852883319571, 1.0]
# 23
# [1.0, 0.92690562683915, 0.92690562683915, 1.0]
# 24
# [1.0, 0.9212920465000387, 0.9212920465000387, 1.0]
# 25
# [1.0, 0.9685800653411, 0.9685800653411, 1.0]
# 26
# [1.0, 0.9706851056895122, 0.9706851056895122, 1.0]
# 27
# [1.0, 0.9495435571663584, 0.9495435571663584, 1.0]
# 28
# [1.0, 0.9722229159470738, 0.9722229159470738, 1.0]
# 29
# [1.0, 0.9999315597328692, 0.9999315597328692, 1.0]
# 30
# [1.0, 0.9600302402228564, 0.9600302402228564, 1.0]
# 31
# [1.0, 0.9525039900268926, 0.9525039900268926, 1.0]
# 32
# [1.0, 0.9172938883734605, 0.9172938883734605, 1.0]
# 33
# [1.0, 0.956762712376009, 0.956762712376009, 1.0]
# 34
# [1.0, 0.9507429098852598, 0.9507429098852598, 1.0]
# 35
# [1.0, 0.9729587284306278, 0.9729587284306278, 1.0]
# 36
# [nan, nan, nan, 1.0]
# 37
# [1.0, 0.9825366575982006, 0.9825366575982006, 1.0]
# 38
# [1.0, 0.9426500523368148, 0.9426500523368148, 1.0]
# 39
# [1.0, 0.953516313259815, 0.953516313259815, 1.0]
# 40
# [1.0, 0.9705628025552455, 0.9705628025552455, 1.0]
# 41
# [1.0, 0.877990915329947, 0.877990915329947, 1.0]
# 42
# [1.0, 0.9627667723526859, 0.9627667723526859, 1.0]
# 43
# [1.0, 0.9719532849936046, 0.9719532849936046, 1.0]
# 44
# [1.0, 0.9197045106033601, 0.9197045106033601, 1.0]
# 45
# [1.0, 0.9718402101191129, 0.9718402101191129, 1.0]
# 46
# [1.0, 0.9602765178053848, 0.9602765178053848, 1.0]
# 47
# [1.0, 0.9716589568292789, 0.9716589568292789, 1.0]
# 48
# [1.0, 0.9339405326247784, 0.9339405326247784, 1.0]
# 49
# [1.0, 0.9827325202409288, 0.9827325202409288, 1.0]
# 50
# [1.0, 0.8812785825495039, 0.8812785825495039, 1.0]
# 51
# [1.0, 0.9337844867649885, 0.9337844867649885, 1.0]
# 52
# [1.0, 0.9306118095975657, 0.9306118095975657, 1.0]
# 53
# [1.0, 0.9299043232391371, 0.9299043232391371, 1.0]
# 54
# [1.0, 0.9635375056931162, 0.9635375056931162, 1.0]
# 55
# [1.0, 0.9677345467822633, 0.9677345467822633, 1.0]
# 56
# [1.0, 0.9276563719555821, 0.9276563719555821, 1.0]
# 57
# [1.0, 0.9474273045097297, 0.9474273045097297, 1.0]
# 58
# [1.0, 0.9778195218630745, 0.9778195218630745, 1.0]
# 59
# [1.0, 0.8876187654477504, 0.8876187654477504, 1.0]
# 60
# [1.0, 0.9803719662969008, 0.9803719662969008, 1.0]
# 61
# [1.0, 0.9899547614542343, 0.9899547614542343, 1.0]
# 62
# [1.0, 0.9847990229347132, 0.9847990229347132, 1.0]
# 63
# [1.0, 0.9103637682840444, 0.9103637682840444, 1.0]
# 64
# [1.0, 0.9583695059040482, 0.9583695059040482, 1.0]
# 65
# [1.0, 0.9019561416295717, 0.9019561416295717, 1.0]
# 66
# [1.0, 0.9094571716823396, 0.9094571716823396, 1.0]
# 67
# [1.0, 0.9402554649805244, 0.9402554649805244, 1.0]
# 68
# [1.0, 0.9598051303281263, 0.9598051303281263, 1.0]
# 69
# [1.0, 0.895019064046842, 0.895019064046842, 1.0]
# 70
# [1.0, 0.9443546561393676, 0.9443546561393676, 1.0]
# 71
# [1.0, 0.9234753486855847, 0.9234753486855847, 1.0]
# 72
# [1.0, 0.9335527419971378, 0.9335527419971378, 1.0]
# 73
# [1.0, 0.9280662498915615, 0.9280662498915615, 1.0]
# 74
# [1.0, 0.9613605784822008, 0.9613605784822008, 1.0]
# 75
# [1.0, 0.9781441352324773, 0.9781441352324773, 1.0]
# 76
# [1.0, 0.9708332677091918, 0.9708332677091918, 1.0]
# 77
# [1.0, 0.9771111199714679, 0.9771111199714679, 1.0]
# 78
# [1.0, 0.9932522898031033, 0.9932522898031033, 1.0]
# 79
# [1.0, 0.9189997260202584, 0.9189997260202584, 1.0]
# 80
# [1.0, 0.9748539593586784, 0.9748539593586784, 1.0]
# 81
# [1.0, 0.9408279354620477, 0.9408279354620477, 1.0]
# 82
# [1.0, 0.9131323246319113, 0.9131323246319113, 1.0]
# 83
# [1.0, 0.9399126976305929, 0.9399126976305929, 1.0]
# 84
# [1.0, 0.9568684585625938, 0.9568684585625938, 1.0]
# 85
# [1.0, 0.9833592859145027, 0.9833592859145027, 1.0]
# 86
# [1.0, 0.9991286460488323, 0.9991286460488323, 1.0]
# 87
# [1.0, 0.9156532698781742, 0.9156532698781742, 1.0]
# 88
# [1.0, 0.9907050415972928, 0.9907050415972928, 1.0]
# 89
# [1.0, 0.9627301213592023, 0.9627301213592023, 1.0]
# 90
# [1.0, 0.978883311035711, 0.978883311035711, 1.0]
# 91
# [1.0, 0.9734983475055177, 0.9734983475055177, 1.0]
# 92
# [1.0, 0.970812971929407, 0.970812971929407, 1.0]
# 93
# [1.0, 0.9610587057765697, 0.9610587057765697, 1.0]
# 94
# [1.0, 0.9546460936836987, 0.9546460936836987, 1.0]
# 95
# [1.0, 0.9894304621735317, 0.9894304621735317, 1.0]
# 96
# [1.0, 0.9408195426114133, 0.9408195426114133, 1.0]
# 97
# [1.0, 0.9334655412136239, 0.9334655412136239, 1.0]
# 98
# [1.0, 0.9375186067856217, 0.9375186067856217, 1.0]
# 99
# [1.0, 0.9865840611647073, 0.9865840611647073, 1.0]
# 100
# [1.0, 0.9454196076670839, 0.9454196076670839, 1.0]
# 101
# [1.0, 0.9198331150504109, 0.9198331150504109, 1.0]
# 102
# [1.0, 0.9603966834340599, 0.9603966834340599, 1.0]
# 103
# [1.0, 0.965157558859589, 0.965157558859589, 1.0]
# 104
# [1.0, 0.9422309038689234, 0.9422309038689234, 1.0]
# 105
# [1.0, 0.9564919155764757, 0.9564919155764757, 1.0]
# 106
# [1.0, 0.9593713825736387, 0.9593713825736387, 1.0]
# 107
# [1.0, 0.9740457159095761, 0.9740457159095761, 1.0]
# 108
# [1.0, 0.9774019874312267, 0.9774019874312267, 1.0]
# 109
# [1.0, 0.9292004335806949, 0.9292004335806949, 1.0]
# 110
# [1.0, 0.9050751728409616, 0.9050751728409616, 1.0]
# 111
# [1.0, 0.9281244541011698, 0.9281244541011698, 1.0]
# 112
# [1.0, 0.9987302020665462, 0.9987302020665462, 1.0]
# 113
# [1.0, 0.8948823517006903, 0.8948823517006903, 1.0]
# 114
# [1.0, 0.9500746625701629, 0.9500746625701629, 1.0]
# 115
# [1.0, 0.9312700812887481, 0.9312700812887481, 1.0]
# 116
# [1.0, 0.9896143399556897, 0.9896143399556897, 1.0]
# 117
# [1.0, 0.9724718923146898, 0.9724718923146898, 1.0]
# 118
# [1.0, 0.9355510535205555, 0.9355510535205555, 1.0]
# 119
# [1.0, 0.9430220866680097, 0.9430220866680097, 1.0]
# 120
# [1.0, 0.9868433823492031, 0.9868433823492031, 1.0]
# 121
# [1.0, 0.9534244581748, 0.9534244581748, 1.0]
# 122
# [nan, nan, nan, 1.0]
# 123
# [nan, nan, nan, 1.0]
# 124
# [1.0, 0.961922459103548, 0.961922459103548, 1.0]
# 125
# [1.0, 0.9267309348245499, 0.9267309348245499, 1.0]
# 126
# [1.0, 0.9482126811213059, 0.9482126811213059, 1.0]
# 127
# [1.0, 0.9202283522151294, 0.9202283522151294, 1.0]
# 128
# [1.0, 0.9824436992676329, 0.9824436992676329, 1.0]
# 129
# [1.0, 0.9352837630923931, 0.9352837630923931, 1.0]
# 130
# [1.0, 0.9416477047860359, 0.9416477047860359, 1.0]
# 131
# [1.0, 0.957555407571937, 0.957555407571937, 1.0]
# 132
# [1.0, 0.9355588421491708, 0.9355588421491708, 1.0]
# 133
# [1.0, 0.9665237308550961, 0.9665237308550961, 1.0]
# 134
# [1.0, 0.9679491192545369, 0.9679491192545369, 1.0]
# 135
# [1.0, 0.9609659837258785, 0.9609659837258785, 1.0]
# 136
# [1.0, 0.93426170161129, 0.93426170161129, 1.0]
# 137
# [1.0, 0.9817030383770007, 0.9817030383770007, 1.0]
# 138
# [1.0, 0.9712161976911842, 0.9712161976911842, 1.0]
# 139
# [1.0, 0.937303875073949, 0.937303875073949, 1.0]
# 140
# [1.0, 0.9575332217190007, 0.9575332217190007, 1.0]
# 141
# [1.0, 0.9321525423582401, 0.9321525423582401, 1.0]
# 142
# [1.0, 0.961157367291107, 0.961157367291107, 1.0]
# 143
# [1.0, 0.9605663280203981, 0.9605663280203981, 1.0]
# 144
# [1.0, 0.9182643838550192, 0.9182643838550192, 1.0]
# 145
# [1.0, 0.9683330632275635, 0.9683330632275635, 1.0]
# 146
# [1.0, 0.9127500900152633, 0.9127500900152633, 1.0]
# 147
# [1.0, 0.9732759499294947, 0.9732759499294947, 1.0]
# 148
# [1.0, 0.8675139249474413, 0.8675139249474413, 1.0]
# 149
# [1.0, 0.9733288580096634, 0.9733288580096634, 1.0]
# 150
# [1.0, 0.9232665738083693, 0.9232665738083693, 1.0]
# 151
# [1.0, 0.9249223432914545, 0.9249223432914545, 1.0]
# 152
# [1.0, 0.8807726034397197, 0.8807726034397197, 1.0]
# 153
# [1.0, 0.9853669480543464, 0.9853669480543464, 1.0]
# 154
# [1.0, 0.9084246407563565, 0.9084246407563565, 1.0]
# 155
# [1.0, 0.9807892229711506, 0.9807892229711506, 1.0]
# 156
# [1.0, 0.9238076755279669, 0.9238076755279669, 1.0]
# 157
# [1.0, 0.9217853824599415, 0.9217853824599415, 1.0]
# 158
# [1.0, 0.9245610655075177, 0.9245610655075177, 1.0]
# 159
# [1.0, 0.9943031696824979, 0.9943031696824979, 1.0]
# 160
# [1.0, 0.9490687576202249, 0.9490687576202249, 1.0]
# 161
# [1.0, 0.9734411607401728, 0.9734411607401728, 1.0]
# 162
# [1.0, 0.975671685736245, 0.975671685736245, 1.0]
# 163
# [1.0, 0.9779073337168043, 0.9779073337168043, 1.0]
# 164
# [1.0, 0.9773094625613571, 0.9773094625613571, 1.0]
# 165
# [1.0, 0.9828553145038544, 0.9828553145038544, 1.0]
# 166
# [1.0, 0.9683758289133382, 0.9683758289133382, 1.0]
# 167
# [1.0, 0.9350815281923367, 0.9350815281923367, 1.0]
# 168
# [1.0, 0.9662008420601215, 0.9662008420601215, 1.0]
# 169
# [1.0, 0.9645351336435242, 0.9645351336435242, 1.0]
# 170
# [1.0, 0.9744080573086948, 0.9744080573086948, 1.0]
# 171
# [1.0, 0.9774692812771095, 0.9774692812771095, 1.0]
# 172
# [1.0, 0.9875012935016253, 0.9875012935016253, 1.0]
# 173
# [1.0, 0.9590051591239637, 0.9590051591239637, 1.0]
# 174
# [1.0, 0.9589478815598209, 0.9589478815598209, 1.0]
# 175
# [1.0, 0.9461927626722428, 0.9461927626722428, 1.0]
# 176
# [1.0, 0.9512877611610076, 0.9512877611610076, 1.0]
# 177
# [1.0, 0.9338206766296733, 0.9338206766296733, 1.0]
# 178
# [1.0, 0.9747539620260861, 0.9747539620260861, 1.0]
# 179
# [1.0, 0.9394712961757258, 0.9394712961757258, 1.0]
# 180
# [1.0, 0.8878627558008586, 0.8878627558008586, 1.0]
# 181
# [1.0, 0.9020613131085481, 0.9020613131085481, 1.0]
# 182
# [1.0, 0.9439480522042771, 0.9439480522042771, 1.0]
# 183
# [1.0, 0.9707377664774273, 0.9707377664774273, 1.0]
# 184
# [1.0, 0.8939154578173142, 0.8939154578173142, 1.0]
# 185
# [1.0, 0.9348844315634887, 0.9348844315634887, 1.0]
# 186
# [1.0, 0.9558491650784046, 0.9558491650784046, 1.0]
# 187
# [1.0, 0.9507776393309723, 0.9507776393309723, 1.0]
# 188
# [1.0, 0.9954331038835869, 0.9954331038835869, 1.0]
# 189
# [1.0, 0.9367393091821983, 0.9367393091821983, 1.0]
# 190
# [1.0, 0.9771586915274567, 0.9771586915274567, 1.0]
# 191
# [1.0, 0.9714625180780097, 0.9714625180780097, 1.0]
# 192
# [1.0, 0.999276414299164, 0.999276414299164, 1.0]
# 193
# [1.0, 0.8745504470464548, 0.8745504470464548, 1.0]
# 194
# [1.0, 0.9791311830667246, 0.9791311830667246, 1.0]
# 195
# [1.0, 0.9582290986250649, 0.9582290986250649, 1.0]
# 196
# [1.0, 0.9581662849392012, 0.9581662849392012, 1.0]
# 197
# [1.0, 0.8940118928550829, 0.8940118928550829, 1.0]
# 198
# [1.0, 0.9413731873712794, 0.9413731873712794, 1.0]
# 199
# [1.0, 0.9507819626676821, 0.9507819626676821, 1.0]
# 200
# [1.0, 0.9273031017488652, 0.9273031017488652, 1.0]
# 201
# [1.0, 0.9474524976616785, 0.9474524976616785, 1.0]
# 202
# [1.0, 0.9674517923870015, 0.9674517923870015, 1.0]
# 203
# [1.0, 0.9651185904675725, 0.9651185904675725, 1.0]
# 204
# [1.0, 0.9380248689244272, 0.9380248689244272, 1.0]
# 205
# [1.0, 0.9372267373047913, 0.9372267373047913, 1.0]
# 206
# [1.0, 0.976857270791237, 0.976857270791237, 1.0]
# 207
# [1.0, 0.9588855602746699, 0.9588855602746699, 1.0]
# 208
# [1.0, 0.9047562879306258, 0.9047562879306258, 1.0]
# 209
# [1.0, 0.8847284743975493, 0.8847284743975493, 1.0]
# 210
# [1.0, 0.866763558422399, 0.866763558422399, 1.0]
# 211
# [1.0, 0.9354564634778744, 0.9354564634778744, 1.0]
# 212
# [1.0, 0.9187169631843967, 0.9187169631843967, 1.0]
# 213
# [1.0, 0.9960785823999175, 0.9960785823999175, 1.0]
# 214
# [1.0, 0.9972471994595117, 0.9972471994595117, 1.0]
# 215
# [1.0, 0.9530000589466747, 0.9530000589466747, 1.0]
# 216
# [1.0, 0.9788866252661765, 0.9788866252661765, 1.0]
# 217
# [1.0, 0.9838039115676098, 0.9838039115676098, 1.0]
# 218
# [1.0, 0.9842259794081303, 0.9842259794081303, 1.0]
# 219
# [1.0, 0.876158746637237, 0.876158746637237, 1.0]
# 220
# [1.0, 0.9540176622540861, 0.9540176622540861, 1.0]
# 221
# [1.0, 0.9851120437602146, 0.9851120437602146, 1.0]
# 222
# [1.0, 0.9976016301892656, 0.9976016301892656, 1.0]
# 223
# [1.0, 0.8891734495282382, 0.8891734495282382, 1.0]
# 224
# [1.0, 0.9769959292448881, 0.9769959292448881, 1.0]
# 225
# [1.0, 0.9474085841998585, 0.9474085841998585, 1.0]
# 226
# [1.0, 0.9928954324766861, 0.9928954324766861, 1.0]
# 227
# [1.0, 0.925846557103593, 0.925846557103593, 1.0]
# 228
# [1.0, 0.9195231573164749, 0.9195231573164749, 1.0]
# 229
# [1.0, 0.9665055522711397, 0.9665055522711397, 1.0]
# 230
# [1.0, 0.9824594669653783, 0.9824594669653783, 1.0]
# 231
# [1.0, 0.9264884734792309, 0.9264884734792309, 1.0]
# 232
# [1.0, 0.9237406566362564, 0.9237406566362564, 1.0]
# 233
# [1.0, 0.94796468024075, 0.94796468024075, 1.0]
# 234
# [1.0, 0.9672300612897242, 0.9672300612897242, 1.0]
# 235
# [1.0, 0.9739528009030981, 0.9739528009030981, 1.0]
# 236
# [1.0, 0.9059707017534311, 0.9059707017534311, 1.0]
# 237
# [1.0, 0.9566069313880009, 0.9566069313880009, 1.0]
# 238
# [1.0, 0.929769287095133, 0.929769287095133, 1.0]
# 239
# [1.0, 0.9142848418591732, 0.9142848418591732, 1.0]
# 240
# [1.0, 0.9552087750409209, 0.9552087750409209, 1.0]
# 241
# [1.0, 0.9910989817468335, 0.9910989817468335, 1.0]
# 242
# [1.0, 0.9368853749247354, 0.9368853749247354, 1.0]
# 243
# [1.0, 0.9818137808991833, 0.9818137808991833, 1.0]
# 244
# [1.0, 0.9790187015022356, 0.9790187015022356, 1.0]
# 245
# [1.0, 0.9620851167271178, 0.9620851167271178, 1.0]
# 246
# [1.0, 0.9676417037658686, 0.9676417037658686, 1.0]
# 247
# [1.0, 0.9094649092188456, 0.9094649092188456, 1.0]
# 248
# [1.0, 0.8771313446866976, 0.8771313446866976, 1.0]
# 249
# [1.0, 0.9066100056220605, 0.9066100056220605, 1.0]
# 250
# [1.0, 0.9875248289991722, 0.9875248289991722, 1.0]
# 251
# [1.0, 0.9917418560961333, 0.9917418560961333, 1.0]
# 252
# [1.0, 0.9794488034045972, 0.9794488034045972, 1.0]
# 253
# [1.0, 0.8900393008204256, 0.8900393008204256, 1.0]
# 254
# [1.0, 0.945957871538572, 0.945957871538572, 1.0]
# 255
# [1.0, 0.9872743430857948, 0.9872743430857948, 1.0]
# 256
# [1.0, 0.9621956924097173, 0.9621956924097173, 1.0]
# 257
# [1.0, 0.9714027541956294, 0.9714027541956294, 1.0]
# 258
# [1.0, 0.9439670588537763, 0.9439670588537763, 1.0]
# 259
# [1.0, 0.9482731329132047, 0.9482731329132047, 1.0]
# 260
# [1.0, 0.9840820480674124, 0.9840820480674124, 1.0]
# 261
# [1.0, 0.9900230605524276, 0.9900230605524276, 1.0]
# 262
# [1.0, 0.9021966624630908, 0.9021966624630908, 1.0]
# 263
# [1.0, 0.8349207149154765, 0.8349207149154765, 1.0]
# 264
# [1.0, 0.8857962177192755, 0.8857962177192755, 1.0]
# 265
# [1.0, 0.9792023349564425, 0.9792023349564425, 1.0]
# 266
# [1.0, 0.9531470938927488, 0.9531470938927488, 1.0]
# 267
# [1.0, 0.9488875373845049, 0.9488875373845049, 1.0]
# 268
# [1.0, 0.9670123152476479, 0.9670123152476479, 1.0]
# 269
# [1.0, 0.8843954604059397, 0.8843954604059397, 1.0]
# 270
# [1.0, 0.9521644926899453, 0.9521644926899453, 1.0]
# 271
# [1.0, 0.9645172538169043, 0.9645172538169043, 1.0]
# 272
# [1.0, 0.9726379351190214, 0.9726379351190214, 1.0]
# 273
# [1.0, 0.9185609320503997, 0.9185609320503997, 1.0]
# 274
# [1.0, 0.9376911169728819, 0.9376911169728819, 1.0]
# 275
# [1.0, 0.9680109797507283, 0.9680109797507283, 1.0]
# 276
# [1.0, 0.9218530539768246, 0.9218530539768246, 1.0]
# 277
# [1.0, 0.932943427212424, 0.932943427212424, 1.0]
# 278
# [1.0, 0.9695772462428697, 0.9695772462428697, 1.0]
# 279
# [1.0, 0.9527316530738321, 0.9527316530738321, 1.0]
# 280
# [1.0, 0.9820836056388063, 0.9820836056388063, 1.0]
# 281
# [1.0, 0.9144374721928468, 0.9144374721928468, 1.0]
# 282
# [1.0, 0.9461779618057694, 0.9461779618057694, 1.0]
# 283
# [1.0, 0.9936980603896661, 0.9936980603896661, 1.0]
# 284
# [1.0, 0.9915476029153143, 0.9915476029153143, 1.0]
# 285
# [1.0, 0.9710205334511195, 0.9710205334511195, 1.0]
# 286
# [1.0, 0.8955952660990912, 0.8955952660990912, 1.0]
# 287
# [1.0, 0.974585266907446, 0.974585266907446, 1.0]
# 288
# [1.0, 0.9898601350286849, 0.9898601350286849, 1.0]
# 289
# [1.0, 0.9368241083454383, 0.9368241083454383, 1.0]
# 290
# [1.0, 0.982190074244167, 0.982190074244167, 1.0]
# 291
# [1.0, 0.9146800750976134, 0.9146800750976134, 1.0]
# 292
# [1.0, 0.9430728980953816, 0.9430728980953816, 1.0]
# 293
# [1.0, 0.915189448567273, 0.915189448567273, 1.0]
# 294
# [1.0, 0.9850439345242268, 0.9850439345242268, 1.0]
# 295
# [1.0, 0.9040770034673752, 0.9040770034673752, 1.0]
# 296
# [1.0, 0.9578824274274541, 0.9578824274274541, 1.0]
# 297
# [1.0, 0.9370507405044304, 0.9370507405044304, 1.0]
# 298
# [1.0, 0.9280555928695695, 0.9280555928695695, 1.0]
# 299
# [1.0, 0.8546760092401441, 0.8546760092401441, 1.0]
# 300
# [1.0, 0.978437230168317, 0.978437230168317, 1.0]
# 301
# [1.0, 0.9790366771901614, 0.9790366771901614, 1.0]
# 302
# [1.0, 0.9803269121063796, 0.9803269121063796, 1.0]
# 303
# [1.0, 0.9705727250138171, 0.9705727250138171, 1.0]
# 304
# [1.0, 0.9500960420040317, 0.9500960420040317, 1.0]
# 305
# [1.0, 0.983705143685475, 0.983705143685475, 1.0]
# 306
# [1.0, 0.9975308585009668, 0.9975308585009668, 1.0]
# 307
# [1.0, 0.904337756772578, 0.904337756772578, 1.0]
# 308
# [1.0, 0.9582134795802828, 0.9582134795802828, 1.0]
# 309
# [1.0, 0.9998498207259497, 0.9998498207259497, 1.0]
# 310
# [1.0, 0.926653108822102, 0.926653108822102, 1.0]
# 311
# [1.0, 0.9686078165721769, 0.9686078165721769, 1.0]
# 312
# [1.0, 0.9374363792525131, 0.9374363792525131, 1.0]
# 313
# [1.0, 0.9810047143996509, 0.9810047143996509, 1.0]
# 314
# [1.0, 0.8814455708106184, 0.8814455708106184, 1.0]
# 315
# [1.0, 0.9516114471794695, 0.9516114471794695, 1.0]
# 316
# [1.0, 0.9658660681093213, 0.9658660681093213, 1.0]
# 317
# [1.0, 0.9310124065482609, 0.9310124065482609, 1.0]
# 318
# [1.0, 0.9399533992596609, 0.9399533992596609, 1.0]
# 319
# [1.0, 0.9999022675766895, 0.9999022675766895, 1.0]
# 320
# [1.0, 0.8714047096934712, 0.8714047096934712, 1.0]
# 321
# [1.0, 0.9472795134180171, 0.9472795134180171, 1.0]
# 322
# [1.0, 0.9194731268481299, 0.9194731268481299, 1.0]
# 323
# [1.0, 0.9553068215537875, 0.9553068215537875, 1.0]
# 324
# [1.0, 0.963804866449083, 0.963804866449083, 1.0]
# 325
# [1.0, 0.9819926420579544, 0.9819926420579544, 1.0]
# 326
# [1.0, 0.9891146567712786, 0.9891146567712786, 1.0]
# 327
# [1.0, 0.9232379704031201, 0.9232379704031201, 1.0]
# 328
# [1.0, 0.9021296047732201, 0.9021296047732201, 1.0]
# 329
# [1.0, 0.9296403907517286, 0.9296403907517286, 1.0]
# 330
# [1.0, 0.9989946841824549, 0.9989946841824549, 1.0]
# 331
# [1.0, 0.9352670536375519, 0.9352670536375519, 1.0]
# 332
# [1.0, 0.9694527028921929, 0.9694527028921929, 1.0]
# 333
# [1.0, 0.9484834541944497, 0.9484834541944497, 1.0]
# 334
# [1.0, 0.9714323334203371, 0.9714323334203371, 1.0]
# 335
# [1.0, 0.9581434312198794, 0.9581434312198794, 1.0]
# 336
# [1.0, 0.9478967530875987, 0.9478967530875987, 1.0]
# 337
# [1.0, 0.9697581694445929, 0.9697581694445929, 1.0]
# 338
# [1.0, 0.9712585984928532, 0.9712585984928532, 1.0]
# 339
# [1.0, 0.9259352038320631, 0.9259352038320631, 1.0]
# 340
# [1.0, 0.9336213291236868, 0.9336213291236868, 1.0]
# 341
# [1.0, 0.9911903720385508, 0.9911903720385508, 1.0]
# 342
# [1.0, 0.9136492689702148, 0.9136492689702148, 1.0]
# 343
# [1.0, 0.909427155077716, 0.909427155077716, 1.0]
# 344
# [1.0, 0.8781169251078401, 0.8781169251078401, 1.0]
# 345
# [1.0, 0.8916956672091536, 0.8916956672091536, 1.0]
# 346
# [1.0, 0.9181479228548314, 0.9181479228548314, 1.0]
# 347
# [1.0, 0.95908339164246, 0.95908339164246, 1.0]
# 348
# [1.0, 0.8847549231987178, 0.8847549231987178, 1.0]
# 349
# [1.0, 0.9012058667208515, 0.9012058667208515, 1.0]
# 350
# [1.0, 0.9690101568291882, 0.9690101568291882, 1.0]
# 351
# [1.0, 0.9768685251807985, 0.9768685251807985, 1.0]
# 352
# [1.0, 0.9120954819592267, 0.9120954819592267, 1.0]
# 353
# [1.0, 0.991034485183871, 0.991034485183871, 1.0]
# 354
# [1.0, 0.971556257592842, 0.971556257592842, 1.0]
# 355
# [1.0, 0.9436849879544974, 0.9436849879544974, 1.0]
# 356
# [1.0, 0.9467956123032453, 0.9467956123032453, 1.0]
# 357
# [1.0, 0.9687508789953941, 0.9687508789953941, 1.0]
# 358
# [1.0, 0.9767014385278119, 0.9767014385278119, 1.0]
# 359
# [1.0, 0.9706701810678885, 0.9706701810678885, 1.0]
# 360
# [1.0, 0.9699643603227842, 0.9699643603227842, 1.0]
# 361
# [1.0, 0.9184715845774372, 0.9184715845774372, 1.0]
# 362
# [nan, nan, nan, 1.0]
# 363
# [1.0, 0.9564794638404022, 0.9564794638404022, 1.0]
# 364
# [1.0, 0.9222416704688535, 0.9222416704688535, 1.0]
# 365
# [1.0, 0.9573282134420465, 0.9573282134420465, 1.0]
# 366
# [1.0, 0.9664503695587205, 0.9664503695587205, 1.0]
# 367
# [1.0, 0.8793300373227833, 0.8793300373227833, 1.0]
# 368
# [1.0, 0.9121671962996223, 0.9121671962996223, 1.0]
# 369
# [1.0, 0.9380878407593419, 0.9380878407593419, 1.0]
# 370
# [1.0, 0.9588879975677725, 0.9588879975677725, 1.0]
# 371
# [1.0, 0.883836466231753, 0.883836466231753, 1.0]
# 372
# [1.0, 0.984215917938517, 0.984215917938517, 1.0]
# 373
# [1.0, 0.9521918950241338, 0.9521918950241338, 1.0]
# 374
# [1.0, 0.9246076955301256, 0.9246076955301256, 1.0]
# 375
# [1.0, 0.9625720330600807, 0.9625720330600807, 1.0]
# 376
# [1.0, 0.9264898198795456, 0.9264898198795456, 1.0]
# 377
# [1.0, 0.8953913352441653, 0.8953913352441653, 1.0]
# 378
# [1.0, 0.9735969358369205, 0.9735969358369205, 1.0]
# 379
# [1.0, 0.9380314131843832, 0.9380314131843832, 1.0]
# 380
# [1.0, 0.992890327485141, 0.992890327485141, 1.0]
# 381
# [1.0, 0.9268840402110032, 0.9268840402110032, 1.0]
# 382
# [1.0, 0.9376509270377725, 0.9376509270377725, 1.0]
# 383
# [1.0, 0.9692908651021667, 0.9692908651021667, 1.0]
# 384
# [1.0, 0.9516069575949415, 0.9516069575949415, 1.0]
# 385
# [1.0, 0.9664699138281024, 0.9664699138281024, 1.0]
# 386
# [1.0, 0.8732714518553273, 0.8732714518553273, 1.0]
# 387
# [1.0, 0.9662243237756408, 0.9662243237756408, 1.0]
# 388
# [1.0, 0.9963286719172428, 0.9963286719172428, 1.0]
# 389
# [1.0, 0.9707374830422716, 0.9707374830422716, 1.0]
# 390
# [1.0, 0.9441965295261662, 0.9441965295261662, 1.0]
# 391
# [1.0, 0.9918428368686891, 0.9918428368686891, 1.0]
# 392
# [1.0, 0.9428648654067104, 0.9428648654067104, 1.0]
# 393
# [1.0, 0.9624259589680602, 0.9624259589680602, 1.0]
# 394
# [1.0, 0.990003338509809, 0.990003338509809, 1.0]
# 395
# [1.0, 0.9335647361484802, 0.9335647361484802, 1.0]
# 396
# [1.0, 0.9697182134515274, 0.9697182134515274, 1.0]
# 397
# [1.0, 0.9662247668560284, 0.9662247668560284, 1.0]
# 398
# [1.0, 0.93046242599622, 0.93046242599622, 1.0]
# 399
# [1.0, 0.9248022741117589, 0.9248022741117589, 1.0]
# 400
# [1.0, 0.9971265968169847, 0.9971265968169847, 1.0]
# 401
# [1.0, 0.9396031199535931, 0.9396031199535931, 1.0]
# 402
# [1.0, 0.9644341089553542, 0.9644341089553542, 1.0]
# 403
# [1.0, 0.8856332069829747, 0.8856332069829747, 1.0]
# 404
# [1.0, 0.9114339427532169, 0.9114339427532169, 1.0]
# 405
# [1.0, 0.9855907021262237, 0.9855907021262237, 1.0]
# 406
# [1.0, 0.9391153027901302, 0.9391153027901302, 1.0]
# 407
# [1.0, 0.9911803842646401, 0.9911803842646401, 1.0]
# 408
# [1.0, 0.996913461356035, 0.996913461356035, 1.0]
# 409
# [1.0, 0.9704711050834898, 0.9704711050834898, 1.0]
# 410
# [1.0, 0.9991154100462794, 0.9991154100462794, 1.0]
# 411
# [1.0, 0.9041180866247853, 0.9041180866247853, 1.0]
# 412
# [1.0, 0.8981176186805657, 0.8981176186805657, 1.0]
# 413
# [1.0, 0.9611966055725399, 0.9611966055725399, 1.0]
# 414
# [1.0, 0.9649422267942905, 0.9649422267942905, 1.0]
# 415
# [1.0, 0.9660237660565446, 0.9660237660565446, 1.0]
# 416
# [1.0, 0.9775722498754238, 0.9775722498754238, 1.0]
# 417
# [1.0, 0.9416913743509548, 0.9416913743509548, 1.0]
# 418
# [1.0, 0.9242275265171302, 0.9242275265171302, 1.0]
# 419
# [1.0, 0.9677813056474431, 0.9677813056474431, 1.0]
# 420
# [1.0, 0.9579999981527981, 0.9579999981527981, 1.0]
# 421
# [1.0, 0.9553735416504926, 0.9553735416504926, 1.0]
# 422
# [1.0, 0.8847297450666131, 0.8847297450666131, 1.0]
# 423
# [1.0, 0.9284306616409731, 0.9284306616409731, 1.0]
# 424
# [1.0, 0.9475872758699371, 0.9475872758699371, 1.0]
# 425
# [1.0, 0.9090463465245335, 0.9090463465245335, 1.0]
# 426
# [1.0, 0.9948643147127901, 0.9948643147127901, 1.0]
# 427
# [1.0, 0.9457009962275197, 0.9457009962275197, 1.0]
# 428
# [1.0, 0.9309028031801937, 0.9309028031801937, 1.0]
# 429
# [1.0, 0.9882896580696303, 0.9882896580696303, 1.0]
# 430
# [1.0, 0.9604919688421444, 0.9604919688421444, 1.0]
# 431
# [1.0, 0.9991541019809088, 0.9991541019809088, 1.0]
# 432
# [1.0, 0.9359069993766626, 0.9359069993766626, 1.0]
# 433
# [1.0, 0.9382342580892399, 0.9382342580892399, 1.0]
# 434
# [1.0, 0.9312355631141207, 0.9312355631141207, 1.0]
# 435
# [1.0, 0.9213460673387485, 0.9213460673387485, 1.0]
# 436
# [1.0, 0.9983531008212551, 0.9983531008212551, 1.0]
# 437
# [1.0, 0.9581690132015218, 0.9581690132015218, 1.0]
# 438
# [1.0, 0.9692574231501069, 0.9692574231501069, 1.0]
# 439
# [1.0, 0.9128695847757371, 0.9128695847757371, 1.0]
# 440
# [1.0, 0.8894056375356698, 0.8894056375356698, 1.0]
# 441
# [1.0, 0.929140384981087, 0.929140384981087, 1.0]
# 442
# [1.0, 0.9319262649232818, 0.9319262649232818, 1.0]
# 443
# [1.0, 0.9673121886345717, 0.9673121886345717, 1.0]
# 444
# [1.0, 0.9290993552580012, 0.9290993552580012, 1.0]
# 445
# [1.0, 0.9674667452257709, 0.9674667452257709, 1.0]
# 446
# [1.0, 0.947958353802186, 0.947958353802186, 1.0]
# 447
# [1.0, 0.9625847088398257, 0.9625847088398257, 1.0]
# 448
# [1.0, 0.9308897715486255, 0.9308897715486255, 1.0]
# 449
# [1.0, 0.8647376801141932, 0.8647376801141932, 1.0]
# 450
# [1.0, 0.983971837684776, 0.983971837684776, 1.0]
# 451
# [1.0, 0.9786148784111506, 0.9786148784111506, 1.0]
# 452
# [1.0, 0.9187838812523335, 0.9187838812523335, 1.0]
# 453
# [1.0, 0.9719483848475381, 0.9719483848475381, 1.0]
# 454
# [1.0, 0.9184468148205404, 0.9184468148205404, 1.0]
# 455
# [1.0, 0.885226388027822, 0.885226388027822, 1.0]
# 456
# [1.0, 0.9430646942396614, 0.9430646942396614, 1.0]
# 457
# [1.0, 0.913558729474938, 0.913558729474938, 1.0]
# 458
# [1.0, 0.9435355989486063, 0.9435355989486063, 1.0]
# 459
# [1.0, 0.9844458312228341, 0.9844458312228341, 1.0]
# 460
# [1.0, 0.9873578315510948, 0.9873578315510948, 1.0]
# 461
# [1.0, 0.9045307471664945, 0.9045307471664945, 1.0]
# 462
# [1.0, 0.916732321983003, 0.916732321983003, 1.0]
# 463
# [1.0, 0.9723586870974421, 0.9723586870974421, 1.0]
# 464
# [1.0, 0.959213405548633, 0.959213405548633, 1.0]
# 465
# [1.0, 0.970566994550456, 0.970566994550456, 1.0]
# 466
# [1.0, 0.9857452668176132, 0.9857452668176132, 1.0]
# 467
# [1.0, 0.9551775561717316, 0.9551775561717316, 1.0]
# 468
# [1.0, 0.9200644092532343, 0.9200644092532343, 1.0]
# 469
# [1.0, 0.9459916351673274, 0.9459916351673274, 1.0]
# 470
# [1.0, 0.9992494249534714, 0.9992494249534714, 1.0]
# 471
# [1.0, 0.9468222077806329, 0.9468222077806329, 1.0]
# 472
# [1.0, 0.9786982084338947, 0.9786982084338947, 1.0]
# 473
# [1.0, 0.9897608030108819, 0.9897608030108819, 1.0]
# 474
# [1.0, 0.9339237697423174, 0.9339237697423174, 1.0]
# 475
# [1.0, 0.977349048062271, 0.977349048062271, 1.0]
# 476
# [1.0, 0.913697751430868, 0.913697751430868, 1.0]
# 477
# [1.0, 0.9331630659415449, 0.9331630659415449, 1.0]
# 478
# [1.0, 0.9776779902648036, 0.9776779902648036, 1.0]
# 479
# [1.0, 0.954976266897946, 0.954976266897946, 1.0]
# 480
# [1.0, 0.9900802638728878, 0.9900802638728878, 1.0]
# 481
# [1.0, 0.9419007514793943, 0.9419007514793943, 1.0]
# 482
# [1.0, 0.9731705940261005, 0.9731705940261005, 1.0]
# 483
# [1.0, 0.9629405424992924, 0.9629405424992924, 1.0]
# 484
# [1.0, 0.8700118870238688, 0.8700118870238688, 1.0]
# 485
# [1.0, 0.9727131476974702, 0.9727131476974702, 1.0]
# 486
# [1.0, 0.9922078591029007, 0.9922078591029007, 1.0]
# 487
# [1.0, 0.9466078056456148, 0.9466078056456148, 1.0]
# 488
# [1.0, 0.9916199250615305, 0.9916199250615305, 1.0]
# 489
# [1.0, 0.9008955051727988, 0.9008955051727988, 1.0]
# 490
# [1.0, 0.8687948494705583, 0.8687948494705583, 1.0]
# 491
# [1.0, 0.9595536482829731, 0.9595536482829731, 1.0]
# 492
# [1.0, 0.9996953686533239, 0.9996953686533239, 1.0]
# 493
# [1.0, 0.9178341378360304, 0.9178341378360304, 1.0]
# 494
# [1.0, 0.9426411964912802, 0.9426411964912802, 1.0]
# 495
# [1.0, 0.9267375333257807, 0.9267375333257807, 1.0]
# 496
# [1.0, 0.9252596072611374, 0.9252596072611374, 1.0]
# 497
# [1.0, 0.9266772532450237, 0.9266772532450237, 1.0]
# 498
# [1.0, 0.9683781397061412, 0.9683781397061412, 1.0]
# 499
# [1.0, 0.960986152382967, 0.960986152382967, 1.0]
# 500
# [1.0, 0.9466510414149059, 0.9466510414149059, 1.0]
# 501
# [1.0, 0.9623028940398872, 0.9623028940398872, 1.0]
# 502
# [1.0, 0.9178873072851692, 0.9178873072851692, 1.0]
# 503
# [1.0, 0.9159430315465361, 0.9159430315465361, 1.0]
# 504
# [1.0, 0.9548775389964904, 0.9548775389964904, 1.0]
# 505
# [1.0, 0.9378727356416916, 0.9378727356416916, 1.0]
# 506
# [1.0, 0.9755481258859372, 0.9755481258859372, 1.0]
# 507
# [1.0, 0.9841931584504249, 0.9841931584504249, 1.0]
# 508
# [1.0, 0.9409082315874615, 0.9409082315874615, 1.0]
# 509
# [1.0, 0.9686950578891081, 0.9686950578891081, 1.0]
# 510
# [1.0, 0.9377190284126485, 0.9377190284126485, 1.0]
# 511
# [1.0, 0.9865758420958002, 0.9865758420958002, 1.0]
# 512
# [1.0, 0.9442664228253635, 0.9442664228253635, 1.0]
# 513
# [1.0, 0.9390358875296976, 0.9390358875296976, 1.0]
# 514
# [1.0, 0.9900362392123762, 0.9900362392123762, 1.0]
# 515
# [1.0, 0.9653407500519214, 0.9653407500519214, 1.0]
# 516
# [1.0, 0.921442460540659, 0.921442460540659, 1.0]
# 517
# [1.0, 0.9861751038330644, 0.9861751038330644, 1.0]
# 518
# [1.0, 0.9767593341720789, 0.9767593341720789, 1.0]
# 519
# [1.0, 0.9191089376023706, 0.9191089376023706, 1.0]
# 520
# [1.0, 0.9869074760086763, 0.9869074760086763, 1.0]
# 521
# [1.0, 0.9578033255955222, 0.9578033255955222, 1.0]
# 522
# [1.0, 0.9535817481790549, 0.9535817481790549, 1.0]
# 523
# [1.0, 0.9305251796347613, 0.9305251796347613, 1.0]
# 524
# [1.0, 0.9792240940421916, 0.9792240940421916, 1.0]
# 525
# [1.0, 0.9392405355770772, 0.9392405355770772, 1.0]
# 526
# [1.0, 0.9460166618676895, 0.9460166618676895, 1.0]
# 527
# [1.0, 0.926782018577212, 0.926782018577212, 1.0]
# 528
# [1.0, 0.9788256565665816, 0.9788256565665816, 1.0]
# 529
# [1.0, 0.9372505151711474, 0.9372505151711474, 1.0]
# 530
# [1.0, 0.9099898823631768, 0.9099898823631768, 1.0]
# 531
# [1.0, 0.9581174382136384, 0.9581174382136384, 1.0]
# 532
# [1.0, 0.97574511875692, 0.97574511875692, 1.0]
# 533
# [1.0, 0.9900185431655281, 0.9900185431655281, 1.0]
# 534
# [1.0, 0.9925051043520303, 0.9925051043520303, 1.0]
# 535
# [1.0, 0.9679240211317603, 0.9679240211317603, 1.0]
# 536
# [1.0, 0.9575919828920147, 0.9575919828920147, 1.0]
# 537
# [1.0, 0.9880967479454257, 0.9880967479454257, 1.0]
# 538
# [1.0, 0.9718094203119689, 0.9718094203119689, 1.0]
# 539
# [1.0, 0.99380927722704, 0.99380927722704, 1.0]
# 540
# [1.0, 0.9378334160424902, 0.9378334160424902, 1.0]
# 541
# [1.0, 0.9283673978068783, 0.9283673978068783, 1.0]
# 542
# [1.0, 0.9241483045247707, 0.9241483045247707, 1.0]
# 543
# [1.0, 0.902060950816956, 0.902060950816956, 1.0]
# 544
# [1.0, 0.9547242866800918, 0.9547242866800918, 1.0]
# 545
# [1.0, 0.945593676748609, 0.945593676748609, 1.0]
# 546
# [1.0, 0.9901632133373244, 0.9901632133373244, 1.0]
# 547
# [1.0, 0.9563321398459121, 0.9563321398459121, 1.0]
# 548
# [1.0, 0.9522672731386739, 0.9522672731386739, 1.0]
# 549
# [1.0, 0.9078146024871051, 0.9078146024871051, 1.0]
# 550
# [1.0, 0.9130439582088256, 0.9130439582088256, 1.0]
# 551
# [1.0, 0.9224191001364442, 0.9224191001364442, 1.0]
# 552
# [1.0, 0.9780735769590587, 0.9780735769590587, 1.0]
# 553
# [1.0, 0.9823548304948467, 0.9823548304948467, 1.0]
# 554
# [1.0, 0.9617912431422433, 0.9617912431422433, 1.0]
# 555
# [1.0, 0.9718980235662639, 0.9718980235662639, 1.0]
# 556
# [1.0, 0.9349533914405824, 0.9349533914405824, 1.0]
# 557
# [1.0, 0.9354133627719177, 0.9354133627719177, 1.0]
# 558
# [1.0, 0.9955054000495777, 0.9955054000495777, 1.0]
# 559
# [1.0, 0.9460782935094337, 0.9460782935094337, 1.0]
# 560
# [1.0, 0.9477380138899707, 0.9477380138899707, 1.0]
# 561
# [1.0, 0.9803933400978971, 0.9803933400978971, 1.0]
# 562
# [1.0, 0.9427087476885228, 0.9427087476885228, 1.0]
# 563
# [1.0, 0.9634445006879742, 0.9634445006879742, 1.0]
# 564
# [1.0, 0.9192537361539124, 0.9192537361539124, 1.0]
# 565
# [1.0, 0.9716342258740667, 0.9716342258740667, 1.0]
# 566
# [1.0, 0.9408326788857478, 0.9408326788857478, 1.0]
# 567
# [1.0, 0.9209449572370229, 0.9209449572370229, 1.0]
# 568
# [1.0, 0.9725179085818974, 0.9725179085818974, 1.0]
# 569
# [1.0, 0.9796105328329555, 0.9796105328329555, 1.0]
# 570
# [1.0, 0.9590785302902626, 0.9590785302902626, 1.0]
# 571
# [1.0, 0.9704134168673235, 0.9704134168673235, 1.0]
# 572
# [1.0, 0.9345899664103074, 0.9345899664103074, 1.0]
# 573
# [1.0, 0.9682630894603403, 0.9682630894603403, 1.0]
# 574
# [1.0, 0.9934765947044555, 0.9934765947044555, 1.0]
# 575
# [1.0, 0.9885479849428688, 0.9885479849428688, 1.0]
# 576
# [nan, nan, nan, 1.0]
# 577
# [1.0, 0.9488022440042682, 0.9488022440042682, 1.0]
# 578
# [1.0, 0.9778510486231545, 0.9778510486231545, 1.0]
# 579
# [1.0, 0.9592282992215385, 0.9592282992215385, 1.0]
# 580
# [1.0, 0.9799437044369409, 0.9799437044369409, 1.0]
# 581
# [1.0, 0.9705900546385673, 0.9705900546385673, 1.0]
# 582
# [nan, nan, nan, 1.0]
