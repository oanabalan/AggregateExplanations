# %%
import openpyxl
import pandas as pd
import numpy as np
from numpy.linalg import norm

feature_names = ['Age', 'TB', 'DB', 'Alkphos', 'Sgpt','TP', 'ALB', 'AG_Ratio', 'Gender']
noOfIterations = 100

def generateRankings(feature_names):
    dataframe = openpyxl.load_workbook("outputLiverKernelShapLOOCV_1.xlsx")
    sheet = dataframe.active
   
    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_KernelShap = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 7
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                list[k].append(row[4].value)
            else:
                list[k].append(row[step].value)
                step = step + 3
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_KernelShap = pd.DataFrame(dict)
    
    for i in range(len(df_KernelShap)):
        list = []
        for j in range(len(feature_names)):
            if df_KernelShap.iloc[i, j] != 0 :
                count = 0
                for k in range(len(feature_names)):
                   if df_KernelShap.iloc[i, k] > df_KernelShap.iloc[i, j]:
                        count = count + 1
                count = count + 1
                list.append(count)
            else:
                list.append(0.1)
        df_KernelShap.loc[i] = list
    
    df_KernelShap.to_excel("rankingsKernelShap.xlsx")
   
    #################################################################
    dataframe = openpyxl.load_workbook("outputLiverTreeShapLOOCV_1.xlsx")
    sheet = dataframe.active
   
    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_TreeShap = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 7
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                list[k].append(row[4].value)
            else:
                list[k].append(row[step].value)
                step = step + 3          
          
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_TreeShap = pd.DataFrame(dict)
   
    for i in range(len(df_TreeShap)):
        list = []
        for j in range(len(feature_names)):
            if df_TreeShap.iloc[i, j] != 0 :
                count = 0
                for k in range(len(feature_names)):
                   if df_TreeShap.iloc[i, k] > df_TreeShap.iloc[i, j]:
                        count = count + 1
                count = count + 1
                list.append(count)
            else:
                list.append(0.1)
        df_TreeShap.loc[i] = list
    
    df_TreeShap.to_excel("rankingsTreeShap.xlsx")    

    ############################################################################
    dataframe = openpyxl.load_workbook("outputLiverLIMELOOCV_100.xlsx")
    sheet = dataframe.active
   
    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_LIME = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 11
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                list[k].append(row[6].value)
            else:
                list[k].append(row[step].value)
                step = step + 5            
            
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_LIME = pd.DataFrame(dict)
   
    for i in range(len(df_LIME)):
        list = []
        for j in range(len(feature_names)):
            if df_LIME.iloc[i, j] != 0 :
                count = 0
                for k in range(len(feature_names)):
                   if df_LIME.iloc[i, k] > df_LIME.iloc[i, j]:
                        count = count + 1
                count = count + 1
                list.append(count)
            else:
                list.append(0.1)
        df_LIME.loc[i] = list
    
    df_LIME.to_excel("rankingsLIME.xlsx")
    ################################################################
    dataframe = openpyxl.load_workbook("outputLiverAnchorLOOCV_100_99thr.xlsx")
    sheet = dataframe.active
   
    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_Anchor = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 7
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                val = row[4].value
                if val == -1:
                    val = 0
                list[k].append(val)
            else:
                val = row[step].value
                if val == -1:
                   val = 0 
                list[k].append(val)
                step = step + 3
        
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_Anchor = pd.DataFrame(dict)
  
    for i in range(len(df_Anchor)):
        list = []
        for j in range(len(feature_names)):
            if df_Anchor.iloc[i, j] != 0 :
                count = 0
                for k in range(len(feature_names)):
                   if df_Anchor.iloc[i, k] > df_Anchor.iloc[i, j]:
                        count = count + 1
                count = count + 1
                list.append(count)
            else:
                list.append(0.1)
        df_Anchor.loc[i] = list
    
    df_Anchor.to_excel("rankingsAnchor.xlsx")

def stackRowsColumns(M, noOfRows, noOfColumns):
    pos = [0] * noOfRows
    for i in range (0, noOfRows):
        pos[i] = i
    
    for i in range(1, noOfRows):
        wsim = [0] * noOfRows
        for j in range(i, noOfRows):
            for k in range(0, i):
                A = M.loc[k]
                B = M.loc[j]
                wsim[j] = wsim[j] + (1 / ( i - k)) * np.dot(A,B)/(norm(A)*norm(B))
        max_value = max(wsim)
        max_index = wsim.index(max_value)
        aux = M.loc[max_index]
        M.loc[max_index] = M.loc[i]
        M.loc[i] = aux
        aux = pos[max_index]
        pos[max_index] = pos[i]
        pos[i] = aux

    
    for i in range(1, noOfColumns):
        wsim = [0] * noOfColumns
        for j in range(i, noOfColumns):
            for k in range(0, i):
                A = M.loc[k]
                B = M.loc[j]
                wsim[j] = wsim[j] + (1 / ( i - k)) * np.dot(A,B)/(norm(A)*norm(B))
        max_value = max(wsim)
        max_index = wsim.index(max_value)
        aux = M.loc[max_index]
        M.loc[max_index] = M.loc[i]
        M.loc[i] = aux
    return pos, M

def cosineSimilarity(A, B):
    return np.dot(A,B)/(norm(A)*norm(B))

def similarityCase(M, i):
    s = 0
    k = i - 1
    for j in range (1, k + 1):
        s = s + cosineSimilarity(M.loc[i], M.loc[i - j]) * (1 / j)
    return s

def similarityMatrix(M, noOfRows):
    s = 0
    for i in range(1, noOfRows):
        s = s + similarityCase(M, i)
    s = s / (noOfRows - 1)
    return s

def GlobalAlign(MSP, MS, noOfRows):
    if similarityMatrix(MSP, noOfRows) >  similarityMatrix(MS, noOfRows):
        max = similarityMatrix(MSP, noOfRows)
        min = similarityMatrix(MS, noOfRows)
    else:
        max = similarityMatrix(MS, noOfRows)
        min = similarityMatrix(MSP, noOfRows)
    return min / max
    #return similarityMatrix(MSP, noOfRows) / similarityMatrix(MS, noOfRows)


def createMSP(MP, MS, noOfRows):
    MS_copy = MS.copy(deep = True)
    MP_copy = MP.copy(deep = True)
    posS, MS_copy = stackRowsColumns(MS_copy, noOfRows, len(feature_names))
    posP, MP_copy = stackRowsColumns(MP_copy, noOfRows, len(feature_names))
    # MSP = pd.DataFrame(columns = feature_names)
    # for i in range(0, noOfRows):
    #     MSP.loc[posP[i]] = MS_copy.loc[posS[i]]
    return GlobalAlign(MP_copy, MS_copy, noOfRows)

generateRankings(feature_names)
# df_KernelShap = pd.read_excel('rankingsKernelShap.xlsx')
# df_KernelShap = df_KernelShap[df_KernelShap.columns[1:]]
# df_TreeShap = pd.read_excel('rankingsTreeShap.xlsx')
# df_TreeShap = df_TreeShap[df_TreeShap.columns[1:]]
# df_LIME = pd.read_excel('rankingsLIME.xlsx')
# df_LIME = df_LIME[df_LIME.columns[1:]]
# df_Anchor = pd.read_excel('rankingsAnchor.xlsx')
# df_Anchor = df_Anchor[df_Anchor.columns[1:]]


# results = pd.DataFrame(columns = ['AA', 'AL', 'AS', 'LA', 'LL', 'LS', 'SA', 'SL', 'SS'])
# noOfInstances = df_KernelShap.shape[0]

# for instance in range(0, noOfInstances):
#     result = []
#     data_Shap = []
#     for i in range(int(noOfIterations / 2)):
#         data_Shap.append(df_KernelShap.loc[instance].values.flatten().tolist())
#         data_Shap.append(df_TreeShap.loc[instance].values.flatten().tolist())
#     M_Shap  = pd.DataFrame(data_Shap, columns = feature_names)
    
#     data_LIME = []
#     for i in range(noOfIterations):
#         data_LIME.append(df_LIME.loc[instance * noOfIterations + i].values.flatten().tolist())
#     M_LIME  = pd.DataFrame(data_LIME, columns = feature_names)
    
#     data_Anchor = []
#     for i in range(noOfIterations):
#         data_Anchor.append(df_Anchor.loc[instance * noOfIterations + i].values.flatten().tolist())
#     M_Anchor  = pd.DataFrame(data_Anchor, columns = feature_names)  

#     MP = M_Anchor
#     MS = M_Anchor
#     result.append(createMSP(MP, MS, noOfIterations))
#     MP = M_Anchor
#     MS = M_LIME
#     result.append(createMSP(MP, MS, noOfIterations))
#     MP = M_Anchor
#     MS = M_Shap
#     result.append(createMSP(MP, MS, noOfIterations))
#     MP = M_LIME
#     MS = M_Anchor
#     result.append(createMSP(MP, MS, noOfIterations))
#     MP = M_LIME
#     MS = M_LIME
#     result.append(createMSP(MP, MS, noOfIterations))
#     MP = M_LIME
#     MS = M_Shap
#     result.append(createMSP(MP, MS, noOfIterations))
#     MP = M_Shap
#     MS = M_Anchor
#     result.append(createMSP(MP, MS, noOfIterations))
#     MP = M_Shap
#     MS = M_LIME
#     result.append(createMSP(MP, MS, noOfIterations))
#     MP = M_Shap
#     MS = M_Shap
#     result.append(createMSP(MP, MS, noOfIterations))
#     print(result)
#     results.loc[instance] = result

# print(results)
# results.to_excel("resultsLiverMPMS_MinMax.xlsx")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 267
#     262     # MSP = pd.DataFrame(columns = feature_names)
#     263     # for i in range(0, noOfRows):
#     264     #     MSP.loc[posP[i]] = MS_copy.loc[posS[i]]
#     265     return GlobalAlign(MP_copy, MS_copy, noOfRows)
# --> 267 generateRankings(feature_names)
#     268 # df_KernelShap = pd.read_excel('rankingsKernelShap.xlsx')
#     269 # df_KernelShap = df_KernelShap[df_KernelShap.columns[1:]]
#     270 # df_TreeShap = pd.read_excel('rankingsTreeShap.xlsx')
#    (...)
#     329 # print(results)
#     330 # results.to_excel("resultsLiverMPMS_MinMax.xlsx")
#
# Cell In[1], line 99, in generateRankings(feature_names)
#      96 df_TreeShap.to_excel("rankingsTreeShap.xlsx")
#      98 ############################################################################
# ---> 99 dataframe = openpyxl.load_workbook("outputLiverLIMELOOCV_100.xlsx")
#     100 sheet = dataframe.active
#     102 list = []
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\reader\excel.py:346, in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     316 """Open the given filename and return the workbook
#     317
#     318 :param filename: the path to open or a file-like object
#    (...)
#     342
#     343 """
#     344 reader = ExcelReader(filename, read_only, keep_vba,
#     345                      data_only, keep_links, rich_text)
# --> 346 reader.read()
#     347 return reader.wb
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\reader\excel.py:301, in ExcelReader.read(self)
#     299 apply_stylesheet(self.archive, self.wb)
#     300 action = "read worksheets"
# --> 301 self.read_worksheets()
#     302 action = "assign names"
#     303 self.parser.assign_names()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\reader\excel.py:237, in ExcelReader.read_worksheets(self)
#     235     ws._rels = rels
#     236     ws_parser = WorksheetReader(ws, fh, self.shared_strings, self.data_only, self.rich_text)
# --> 237     ws_parser.bind_all()
#     239 # assign any comments to cells
#     240 for r in rels.find(COMMENTS_NS):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\_reader.py:465, in WorksheetReader.bind_all(self)
#     464 def bind_all(self):
# --> 465     self.bind_cells()
#     466     self.bind_merged_cells()
#     467     self.bind_hyperlinks()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\_reader.py:368, in WorksheetReader.bind_cells(self)
#     367 def bind_cells(self):
# --> 368     for idx, row in self.parser.parse():
#     369         for cell in row:
#     370             style = self.ws.parent._cell_styles[cell['style_id']]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\_reader.py:156, in WorkSheetParser.parse(self)
#     137 properties = {
#     138     PRINT_TAG: ('print_options', PrintOptions),
#     139     MARGINS_TAG: ('page_margins', PageMargins),
#    (...)
#     151
#     152 }
#     154 it = iterparse(self.source) # add a finaliser to close the source when this becomes possible
# --> 156 for _, element in it:
#     157     tag_name = element.tag
#     158     if tag_name in dispatcher:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\xml\etree\ElementTree.py:1256, in iterparse.<locals>.iterator()
#    1254 yield from pullparser.read_events()
#    1255 # load event buffer
# -> 1256 data = source.read(16 * 1024)
#    1257 if not data:
#    1258     break
#
# File ~\AppData\Local\Programs\Python\Python310\lib\zipfile.py:923, in ZipExtFile.read(self, n)
#     921 self._offset = 0
#     922 while n > 0 and not self._eof:
# --> 923     data = self._read1(n)
#     924     if n < len(data):
#     925         self._readbuffer = data
#
# File ~\AppData\Local\Programs\Python\Python310\lib\zipfile.py:999, in ZipExtFile._read1(self, n)
#     997 elif self._compress_type == ZIP_DEFLATED:
#     998     n = max(n, self.MIN_READ_SIZE)
# --> 999     data = self._decompressor.decompress(data, n)
#    1000     self._eof = (self._decompressor.eof or
#    1001                  self._compress_left <= 0 and
#    1002                  not self._decompressor.unconsumed_tail)
#    1003     if self._eof:
#
# KeyboardInterrupt:
