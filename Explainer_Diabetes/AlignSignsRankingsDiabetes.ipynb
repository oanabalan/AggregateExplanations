# %%
import openpyxl
import pandas as pd
import numpy as np
from numpy.linalg import norm

feature_names = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI','DiabetesPedigreeFunction', 'Age']
feature_names2 = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI','DiabetesPedigreeFunction', 'Age',
                 'Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI','DiabetesPedigreeFunction', 'Age']
noOfIterations = 100

def convertSign(value):
    if value == "positive":
        return 1
    elif value == "negative":
        return 0
    else
        return -1

def generateSignsRankings(feature_names):
    dataframe = openpyxl.load_workbook("outputDiabetesKernelShapLOOCV_1.xlsx")
    sheet = dataframe.active
   
    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_KernelShapRankings = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 7
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                list[k].append(row[4].value)
            else:
                list[k].append(row[step].value)
                step = step + 3
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_KernelShapRankings = pd.DataFrame(dict)
    
    for i in range(len(df_KernelShapRankings)):
        list = []
        for j in range(len(feature_names)):
            count = 0
            for k in range(len(feature_names)):
               if df_KernelShapRankings.iloc[i, k] > df_KernelShapRankings.iloc[i, j]:
                    count = count + 1
            count = count + 1
            list.append(count)
        df_KernelShapRankings.loc[i] = list

    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_KernelShapSigns = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 6
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                list[k].append(convertSign(row[3].value))
            else:
                list[k].append(convertSign(row[step].value))
                step = step + 3
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_KernelShapSigns = pd.DataFrame(dict)
  
    df_KernelShap = pd.concat([df_KernelShapRankings, df_KernelShapSigns], axis = 1)
    
    df_KernelShap.to_excel("signs_rankingsDiabetesKernelShap.xlsx")
   
    #################################################################
    dataframe = openpyxl.load_workbook("outputDiabetesTreeShapLOOCV_1.xlsx")
    sheet = dataframe.active
   
    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_TreeShapRankings = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 7
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                list[k].append(row[4].value)
            else:
                list[k].append(row[step].value)
                step = step + 3          
          
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_TreeShapRankings = pd.DataFrame(dict)
   
    for i in range(len(df_TreeShapRankings)):
        list = []
        for j in range(len(feature_names)):
            count = 0
            for k in range(len(feature_names)):
               if df_TreeShapRankings.iloc[i, k] > df_TreeShapRankings.iloc[i, j]:
                    count = count + 1
            count = count + 1
            list.append(count)
        df_TreeShapRankings.loc[i] = list


    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_TreeShapSigns = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 6
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                list[k].append(convertSign(row[3].value))
            else:
                list[k].append(convertSign(row[step].value))
                step = step + 3          
          
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_TreeShapSigns = pd.DataFrame(dict)

    df_TreeShap = pd.concat([df_TreeShapRankings, df_TreeShapSigns], axis = 1)

    df_TreeShap.to_excel("signs_rankingsDiabetesTreeShap.xlsx")    

    # ############################################################################
    dataframe = openpyxl.load_workbook("outputDiabetesLIMELOOCV_100.xlsx")
    sheet = dataframe.active
    feature_names = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI','DiabetesPedigreeFunction', 'Age']
    
    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_LIMERankings = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 11
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                list[k].append(row[6].value)
            else:
                list[k].append(row[step].value)
                step = step + 5            
            
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_LIMERankings = pd.DataFrame(dict)
   
    for i in range(len(df_LIMERankings)):
        list = []
        for j in range(len(feature_names)):
            count = 0
            for k in range(len(feature_names)):
               if df_LIMERankings.iloc[i, k] > df_LIMERankings.iloc[i, j]:
                    count = count + 1
            count = count + 1
            list.append(count)
        df_LIMERankings.loc[i] = list


    list = []
    for i in range(len(feature_names)):
        list_feature = []
        list.append(list_feature)
    
    df_LIMESigns = pd.DataFrame()
    
    for i, row in enumerate(sheet):
        step = 10
        if i == 0: 
            continue
        for k in range(len(feature_names)):
            if k == 0:
                list[k].append(convertSign(row[5].value))
            else:
                list[k].append(convertSign(row[step].value))
                step = step + 5            
            
    dict = {}
    for i in range(len(feature_names)):
        new_data = {feature_names[i]: list[i]} 
        dict.update(new_data)
        
    df_LIMESigns = pd.DataFrame(dict)
    df_LIME = pd.concat([df_LIMERankings, df_LIMESigns], axis = 1)

    df_LIME.to_excel("signs_rankingsDiabetesLIME.xlsx")
    ################################################################
    

def stackRowsColumns(M, noOfRows, noOfColumns):
    pos = [0] * noOfRows
    for i in range (0, noOfRows):
        pos[i] = i
    
    for i in range(1, noOfRows):
        wsim = [0] * noOfRows
        for j in range(i, noOfRows):
            for k in range(0, i):
                A = M.loc[k]
                B = M.loc[j]
                wsim[j] = wsim[j] + (1 / ( i - k)) * np.dot(A,B)/(norm(A)*norm(B))
        max_value = max(wsim)
        max_index = wsim.index(max_value)
        aux = M.loc[max_index]
        M.loc[max_index] = M.loc[i]
        M.loc[i] = aux
        aux = pos[max_index]
        pos[max_index] = pos[i]
        pos[i] = aux

    
    # for i in range(1, noOfColumns):
    #     wsim = [0] * noOfColumns
    #     for j in range(i, noOfColumns):
    #         for k in range(0, i):
    #             A = M.loc[k]
    #             B = M.loc[j]
    #             wsim[j] = wsim[j] + (1 / ( i - k)) * np.dot(A,B)/(norm(A)*norm(B))
    #     max_value = max(wsim)
    #     max_index = wsim.index(max_value)
    #     aux = M.loc[max_index]
    #     M.loc[max_index] = M.loc[i]
    #     M.loc[i] = aux
    return pos, M

def cosineSimilarity(A, B):
    return np.dot(A,B)/(norm(A)*norm(B))

def similarityCase(M, i):
    s = 0
    k = i - 1
    for j in range (1, k + 1):
        s = s + cosineSimilarity(M.loc[i], M.loc[i - j]) * (1 / j)
    return s

def similarityMatrix(M, noOfRows):
    s = 0
    for i in range(1, noOfRows):
        s = s + similarityCase(M, i)
    s = s / (noOfRows - 1)
    return s

def GlobalAlign(MSP, MS, noOfRows):
    if similarityMatrix(MSP, noOfRows) >  similarityMatrix(MS, noOfRows):
        max = similarityMatrix(MSP, noOfRows)
        min = similarityMatrix(MS, noOfRows)
    else:
        max = similarityMatrix(MS, noOfRows)
        min = similarityMatrix(MSP, noOfRows)
    return min / max
    # return similarityMatrix(MSP, noOfRows) / similarityMatrix(MS, noOfRows)


def createMSP(MP, MS, noOfRows):
    MS_copy = MS.copy(deep = True)
    MP_copy = MP.copy(deep = True)
    posS, MS_copy = stackRowsColumns(MS_copy, noOfRows, 2 * len(feature_names))
    posP, MP_copy = stackRowsColumns(MP_copy, noOfRows, 2 * len(feature_names))
    # MSP = pd.DataFrame(columns = feature_names2)
    # for i in range(0, noOfRows):
    #     MSP.loc[posP[i]] = MS_copy.loc[posS[i]]
    return GlobalAlign(MP_copy, MS_copy, noOfRows)

generateSignsRankings(feature_names)
df_KernelShap = pd.read_excel('signs_rankingsDiabetesKernelShap.xlsx')
df_KernelShap = df_KernelShap[df_KernelShap.columns[1:]]
df_TreeShap = pd.read_excel('signs_rankingsDiabetesTreeShap.xlsx')
df_TreeShap = df_TreeShap[df_TreeShap.columns[1:]]
df_LIME = pd.read_excel('signs_rankingsDiabetesLIME.xlsx')
df_LIME = df_LIME[df_LIME.columns[1:]]


results = pd.DataFrame(columns = ['LL', 'LS', 'SL', 'SS'])
noOfInstances = df_KernelShap.shape[0]
for instance in range(0, noOfInstances):
    print(instance)
    result = []
    data_Shap = []
    for i in range(int(noOfIterations / 2)):
        data_Shap.append(df_KernelShap.loc[instance].values.flatten().tolist())
        data_Shap.append(df_TreeShap.loc[instance].values.flatten().tolist())
    M_Shap  = pd.DataFrame(data_Shap, columns = feature_names2)
    
    data_LIME = []
    for i in range(noOfIterations):
        data_LIME.append(df_LIME.loc[instance * noOfIterations + i].values.flatten().tolist())
    M_LIME  = pd.DataFrame(data_LIME, columns = feature_names2)
    
    MP = M_LIME
    MS = M_LIME
    result.append(createMSP(MP, MS, noOfIterations))
    MP = M_LIME
    MS = M_Shap
    result.append(createMSP(MP, MS, noOfIterations))
    MP = M_Shap
    MS = M_LIME
    result.append(createMSP(MP, MS, noOfIterations))
    MP = M_Shap
    MS = M_Shap
    result.append(createMSP(MP, MS, noOfIterations))
    print(result)
    results.loc[instance] = result


results.to_excel("resultsSignsRankingsDiabetesMPMS_MinMax.xlsx")
# Out:
# 0
# [1.0, 0.960202450043656, 0.960202450043656, 1.0]
# 1
# [1.0, 0.9839557298168893, 0.9839557298168893, 1.0]
# 2
# [1.0, 0.9790518152356978, 0.9790518152356978, 1.0]
# 3
# [1.0, 0.9645461226927003, 0.9645461226927003, 1.0]
# 4
# [1.0, 0.9241426431547555, 0.9241426431547555, 1.0]
# 5
# [1.0, 0.9218983020059965, 0.9218983020059965, 1.0]
# 6
# [1.0, 0.9708144830841645, 0.9708144830841645, 1.0]
# 7
# [1.0, 0.9454489801124543, 0.9454489801124543, 1.0]
# 8
# [1.0, 0.9660798362477494, 0.9660798362477494, 1.0]
# 9
# [1.0, 0.9387928881252733, 0.9387928881252733, 1.0]
# 10
# [1.0, 0.8591254265884062, 0.8591254265884062, 1.0]
# 11
# [1.0, 0.9144487078628755, 0.9144487078628755, 1.0]
# 12
# [1.0, 0.8599007982988442, 0.8599007982988442, 1.0]
# 13
# [1.0, 0.9757532939842792, 0.9757532939842792, 1.0]
# 14
# [1.0, 0.9472364044822282, 0.9472364044822282, 1.0]
# 15
# [1.0, 0.928515914095276, 0.928515914095276, 1.0]
# 16
# [1.0, 0.988938708607524, 0.988938708607524, 1.0]
# 17
# [1.0, 0.9535550619700842, 0.9535550619700842, 1.0]
# 18
# [1.0, 0.961556612071868, 0.961556612071868, 1.0]
# 19
# [1.0, 0.9365425104320374, 0.9365425104320374, 1.0]
# 20
# [1.0, 0.9452795695247358, 0.9452795695247358, 1.0]
# 21
# [1.0, 0.9683126592070899, 0.9683126592070899, 1.0]
# 22
# [1.0, 0.9083991468265143, 0.9083991468265143, 1.0]
# 23
# [1.0, 0.9986817603423973, 0.9986817603423973, 1.0]
# 24
# [1.0, 0.8959559338780283, 0.8959559338780283, 1.0]
# 25
# [1.0, 0.9173906087888756, 0.9173906087888756, 1.0]
# 26
# [1.0, 0.9586740002069606, 0.9586740002069606, 1.0]
# 27
# [1.0, 0.9985373878738935, 0.9985373878738935, 1.0]
# 28
# [1.0, 0.9558412737196387, 0.9558412737196387, 1.0]
# 29
# [1.0, 0.8548649869174241, 0.8548649869174241, 1.0]
# 30
# [1.0, 0.932265751872281, 0.932265751872281, 1.0]
# 31
# [1.0, 0.9622872270114495, 0.9622872270114495, 1.0]
# 32
# [1.0, 0.9666202226771823, 0.9666202226771823, 1.0]
# 33
# [1.0, 0.9654674547030179, 0.9654674547030179, 1.0]
# 34
# [1.0, 0.9069971044134202, 0.9069971044134202, 1.0]
# 35
# [1.0, 0.9541818274031921, 0.9541818274031921, 1.0]
# 36
# [1.0, 0.9904086355425136, 0.9904086355425136, 1.0]
# 37
# [1.0, 0.9132535486615297, 0.9132535486615297, 1.0]
# 38
# [1.0, 0.9499169141249695, 0.9499169141249695, 1.0]
# 39
# [1.0, 0.8983491394514591, 0.8983491394514591, 1.0]
# 40
# [1.0, 0.9697605299836932, 0.9697605299836932, 1.0]
# 41
# [1.0, 0.9255835087921218, 0.9255835087921218, 1.0]
# 42
# [1.0, 0.9321974444137083, 0.9321974444137083, 1.0]
# 43
# [1.0, 0.9779990295630162, 0.9779990295630162, 1.0]
# 44
# [1.0, 0.9314522552773453, 0.9314522552773453, 1.0]
# 45
# [1.0, 0.9619810316577848, 0.9619810316577848, 1.0]
# 46
# [1.0, 0.9884298471427962, 0.9884298471427962, 1.0]
# 47
# [1.0, 0.9915168726076402, 0.9915168726076402, 1.0]
# 48
# [1.0, 0.9689030134893153, 0.9689030134893153, 1.0]
# 49
# [1.0, 0.9530052666754896, 0.9530052666754896, 1.0]
# 50
# [1.0, 0.9859026872804758, 0.9859026872804758, 1.0]
# 51
# [1.0, 0.997281607720834, 0.997281607720834, 1.0]
# 52
# [1.0, 0.9921225617940875, 0.9921225617940875, 1.0]
# 53
# [1.0, 0.999661381919898, 0.999661381919898, 1.0]
# 54
# [1.0, 0.9328966371844946, 0.9328966371844946, 1.0]
# 55
# [1.0, 0.9939366753816906, 0.9939366753816906, 1.0]
# 56
# [1.0, 0.9454768484190093, 0.9454768484190093, 1.0]
# 57
# [1.0, 0.9937091023010927, 0.9937091023010927, 1.0]
# 58
# [1.0, 0.9672882522500359, 0.9672882522500359, 1.0]
# 59
# [1.0, 0.9509203197658077, 0.9509203197658077, 1.0]
# 60
# [1.0, 0.9737240349039518, 0.9737240349039518, 1.0]
# 61
# [1.0, 0.8891877834595272, 0.8891877834595272, 1.0]
# 62
# [1.0, 0.9828248957943418, 0.9828248957943418, 1.0]
# 63
# [1.0, 0.9938806015070786, 0.9938806015070786, 1.0]
# 64
# [1.0, 0.9485453745281113, 0.9485453745281113, 1.0]
# 65
# [1.0, 0.9354999140442594, 0.9354999140442594, 1.0]
# 66
# [1.0, 0.9428206555629005, 0.9428206555629005, 1.0]
# 67
# [1.0, 0.9612021918304099, 0.9612021918304099, 1.0]
# 68
# [1.0, 0.9811881790531534, 0.9811881790531534, 1.0]
# 69
# [1.0, 0.942955526954488, 0.942955526954488, 1.0]
# 70
# [1.0, 0.9577100720287808, 0.9577100720287808, 1.0]
# 71
# [1.0, 0.8992233422547595, 0.8992233422547595, 1.0]
# 72
# [1.0, 0.980526553519313, 0.980526553519313, 1.0]
# 73
# [1.0, 0.9709959434760304, 0.9709959434760304, 1.0]
# 74
# [1.0, 0.9633755265273798, 0.9633755265273798, 1.0]
# 75
# [1.0, 0.935274234961046, 0.935274234961046, 1.0]
# 76
# [1.0, 0.9348399573693187, 0.9348399573693187, 1.0]
# 77
# [1.0, 0.9799826658471854, 0.9799826658471854, 1.0]
# 78
# [1.0, 0.9668013025907465, 0.9668013025907465, 1.0]
# 79
# [1.0, 0.9416027859703002, 0.9416027859703002, 1.0]
# 80
# [1.0, 0.9581227817944199, 0.9581227817944199, 1.0]
# 81
# [1.0, 0.9602771871655154, 0.9602771871655154, 1.0]
# 82
# [1.0, 0.9278837162156474, 0.9278837162156474, 1.0]
# 83
# [1.0, 0.9983561606819982, 0.9983561606819982, 1.0]
# 84
# [1.0, 0.9731074287378473, 0.9731074287378473, 1.0]
# 85
# [1.0, 0.8946195359480459, 0.8946195359480459, 1.0]
# 86
# [1.0, 0.9183804362605023, 0.9183804362605023, 1.0]
# 87
# [1.0, 0.9769617509483576, 0.9769617509483576, 1.0]
# 88
# [1.0, 0.9368200316188422, 0.9368200316188422, 1.0]
# 89
# [1.0, 0.915585633192422, 0.915585633192422, 1.0]
# 90
# [1.0, 0.9904577894856172, 0.9904577894856172, 1.0]
# 91
# [1.0, 0.9991374581501519, 0.9991374581501519, 1.0]
# 92
# [1.0, 0.9738195585229044, 0.9738195585229044, 1.0]
# 93
# [1.0, 0.9746942959840287, 0.9746942959840287, 1.0]
# 94
# [1.0, 0.9151422113342943, 0.9151422113342943, 1.0]
# 95
# [1.0, 0.9762015868411852, 0.9762015868411852, 1.0]
# 96
# [1.0, 0.9791738569818301, 0.9791738569818301, 1.0]
# 97
# [1.0, 0.9663894904832482, 0.9663894904832482, 1.0]
# 98
# [1.0, 0.974249341824428, 0.974249341824428, 1.0]
# 99
# [1.0, 0.9589292936604852, 0.9589292936604852, 1.0]
# 100
# [1.0, 0.9172795295530916, 0.9172795295530916, 1.0]
# 101
# [1.0, 0.9805039235667925, 0.9805039235667925, 1.0]
# 102
# [1.0, 0.9986781126444252, 0.9986781126444252, 1.0]
# 103
# [1.0, 0.9990291494778656, 0.9990291494778656, 1.0]
# 104
# [1.0, 0.9416290860022528, 0.9416290860022528, 1.0]
# 105
# [1.0, 0.981071635742843, 0.981071635742843, 1.0]
# 106
# [1.0, 0.9926521929328345, 0.9926521929328345, 1.0]
# 107
# [1.0, 0.9634587302676622, 0.9634587302676622, 1.0]
# 108
# [1.0, 0.9423468552740398, 0.9423468552740398, 1.0]
# 109
# [1.0, 0.9428347914062649, 0.9428347914062649, 1.0]
# 110
# [1.0, 0.9491385304067683, 0.9491385304067683, 1.0]
# 111
# [1.0, 0.9864940237351489, 0.9864940237351489, 1.0]
# 112
# [1.0, 0.9532186710828083, 0.9532186710828083, 1.0]
# 113
# [1.0, 0.9176168358997703, 0.9176168358997703, 1.0]
# 114
# [1.0, 0.9388972151149664, 0.9388972151149664, 1.0]
# 115
# [nan, nan, nan, 1.0]
# 116
# [1.0, 0.9892743323691775, 0.9892743323691775, 1.0]
# 117
# [1.0, 0.9189632332206813, 0.9189632332206813, 1.0]
# 118
# [1.0, 0.9661895314909791, 0.9661895314909791, 1.0]
# 119
# [1.0, 0.989976260963834, 0.989976260963834, 1.0]
# 120
# [1.0, 0.9493547869182545, 0.9493547869182545, 1.0]
# 121
# [1.0, 0.936572506552088, 0.936572506552088, 1.0]
# 122
# [1.0, 0.9608987371694995, 0.9608987371694995, 1.0]
# 123
# [1.0, 0.9358978122509399, 0.9358978122509399, 1.0]
# 124
# [1.0, 0.9225434269848072, 0.9225434269848072, 1.0]
# 125
# [1.0, 0.9676594447389152, 0.9676594447389152, 1.0]
# 126
# [1.0, 0.9680232060678257, 0.9680232060678257, 1.0]
# 127
# [1.0, 0.9893479886145331, 0.9893479886145331, 1.0]
# 128
# [1.0, 0.9071130706134667, 0.9071130706134667, 1.0]
# 129
# [1.0, 0.9862587896739812, 0.9862587896739812, 1.0]
# 130
# [1.0, 0.9960264565554089, 0.9960264565554089, 1.0]
# 131
# [1.0, 0.9470995674157062, 0.9470995674157062, 1.0]
# 132
# [1.0, 0.9541096454289573, 0.9541096454289573, 1.0]
# 133
# [1.0, 0.9317524498687956, 0.9317524498687956, 1.0]
# 134
# [1.0, 0.9934718048004286, 0.9934718048004286, 1.0]
# 135
# [1.0, 0.8847035086385279, 0.8847035086385279, 1.0]
# 136
# [1.0, 0.9582011851406255, 0.9582011851406255, 1.0]
# 137
# [1.0, 0.9786679035388198, 0.9786679035388198, 1.0]
# 138
# [1.0, 0.9472701201801381, 0.9472701201801381, 1.0]
# 139
# [1.0, 0.9374191135645599, 0.9374191135645599, 1.0]
# 140
# [1.0, 0.9621391694893783, 0.9621391694893783, 1.0]
# 141
# [1.0, 0.9806786608212938, 0.9806786608212938, 1.0]
# 142
# [nan, nan, nan, 1.0]
# 143
# [1.0, 0.9968717836416973, 0.9968717836416973, 1.0]
# 144
# [1.0, 0.9102151638591947, 0.9102151638591947, 1.0]
# 145
# [1.0, 0.9764956838934435, 0.9764956838934435, 1.0]
# 146
# [1.0, 0.9358905276827417, 0.9358905276827417, 1.0]
# 147
# [1.0, 0.8962267514014104, 0.8962267514014104, 1.0]
# 148
# [1.0, 0.9478159113656162, 0.9478159113656162, 1.0]
# 149
# [1.0, 0.9486468203454802, 0.9486468203454802, 1.0]
# 150
# [1.0, 0.9936440952256447, 0.9936440952256447, 1.0]
# 151
# [1.0, 0.9630155188231087, 0.9630155188231087, 1.0]
# 152
# [1.0, 0.9212466767193735, 0.9212466767193735, 1.0]
# 153
# [1.0, 0.9952545160880508, 0.9952545160880508, 1.0]
# 154
# [1.0, 0.9093139556416656, 0.9093139556416656, 1.0]
# 155
# [1.0, 0.9320629162870191, 0.9320629162870191, 1.0]
# 156
# [1.0, 0.9685724796515883, 0.9685724796515883, 1.0]
# 157
# [1.0, 0.9292280003507528, 0.9292280003507528, 1.0]
# 158
# [1.0, 0.9893183478518102, 0.9893183478518102, 1.0]
# 159
# [1.0, 0.9373503205704345, 0.9373503205704345, 1.0]
# 160
# [1.0, 0.9401031729168833, 0.9401031729168833, 1.0]
# 161
# [1.0, 0.9411355220208121, 0.9411355220208121, 1.0]
# 162
# [1.0, 0.9204206998386083, 0.9204206998386083, 1.0]
# 163
# [1.0, 0.9880364451487968, 0.9880364451487968, 1.0]
# 164
# [1.0, 0.8877247800498764, 0.8877247800498764, 1.0]
# 165
# [1.0, 0.9355004250368133, 0.9355004250368133, 1.0]
# 166
# [1.0, 0.9555639264213843, 0.9555639264213843, 1.0]
# 167
# [1.0, 0.9528549121546807, 0.9528549121546807, 1.0]
# 168
# [1.0, 0.9783779466699252, 0.9783779466699252, 1.0]
# 169
# [1.0, 0.959996038893986, 0.959996038893986, 1.0]
# 170
# [1.0, 0.9485227342186598, 0.9485227342186598, 1.0]
# 171
# [1.0, 0.9582944842888491, 0.9582944842888491, 1.0]
# 172
# [1.0, 0.9365435859940954, 0.9365435859940954, 1.0]
# 173
# [1.0, 0.954056428217171, 0.954056428217171, 1.0]
# 174
# [1.0, 0.9485011055294266, 0.9485011055294266, 1.0]
# 175
# [1.0, 0.9015388429816418, 0.9015388429816418, 1.0]
# 176
# [1.0, 0.9978902800974685, 0.9978902800974685, 1.0]
# 177
# [1.0, 0.9677414867681802, 0.9677414867681802, 1.0]
# 178
# [1.0, 0.9637163836356697, 0.9637163836356697, 1.0]
# 179
# [1.0, 0.9456400424445558, 0.9456400424445558, 1.0]
# 180
# [1.0, 0.9440458236090251, 0.9440458236090251, 1.0]
# 181
# [1.0, 0.8855831321153161, 0.8855831321153161, 1.0]
# 182
# [1.0, 0.9108727132519054, 0.9108727132519054, 1.0]
# 183
# [1.0, 0.988705792864751, 0.988705792864751, 1.0]
# 184
# [1.0, 0.971877740124359, 0.971877740124359, 1.0]
# 185
# [1.0, 0.9394651063066652, 0.9394651063066652, 1.0]
# 186
# [1.0, 0.9703048517708636, 0.9703048517708636, 1.0]
# 187
# [1.0, 0.9297577896522476, 0.9297577896522476, 1.0]
# 188
# [1.0, 0.9491340628144561, 0.9491340628144561, 1.0]
# 189
# [1.0, 0.9875665766751544, 0.9875665766751544, 1.0]
# 190
# [1.0, 0.9286241302373477, 0.9286241302373477, 1.0]
# 191
# [1.0, 0.9560218300104363, 0.9560218300104363, 1.0]
# 192
# [1.0, 0.8925823659767225, 0.8925823659767225, 1.0]
# 193
# [1.0, 0.9538063723839528, 0.9538063723839528, 1.0]
# 194
# [1.0, 0.964817400468562, 0.964817400468562, 1.0]
# 195
# [1.0, 0.9684599781829684, 0.9684599781829684, 1.0]
# 196
# [1.0, 0.9697056807881028, 0.9697056807881028, 1.0]
# 197
# [1.0, 0.9928039421750147, 0.9928039421750147, 1.0]
# 198
# [1.0, 0.9679432237549445, 0.9679432237549445, 1.0]
# 199
# [1.0, 0.9068262372187814, 0.9068262372187814, 1.0]
# 200
# [1.0, 0.8894594241678627, 0.8894594241678627, 1.0]
# 201
# [1.0, 0.8954760868988243, 0.8954760868988243, 1.0]
# 202
# [1.0, 0.8521582816807585, 0.8521582816807585, 1.0]
# 203
# [1.0, 0.9733675325003461, 0.9733675325003461, 1.0]
# 204
# [1.0, 0.9530245758539284, 0.9530245758539284, 1.0]
# 205
# [1.0, 0.9846106583433655, 0.9846106583433655, 1.0]
# 206
# [1.0, 0.9784439209321322, 0.9784439209321322, 1.0]
# 207
# [nan, nan, nan, 1.0]
# 208
# [1.0, 0.9531795701850321, 0.9531795701850321, 1.0]
# 209
# [1.0, 0.9622693304992684, 0.9622693304992684, 1.0]
# 210
# [1.0, 0.9835141335320418, 0.9835141335320418, 1.0]
# 211
# [1.0, 0.9408101606150951, 0.9408101606150951, 1.0]
# 212
# [1.0, 0.9588219541630495, 0.9588219541630495, 1.0]
# 213
# [1.0, 0.9920999130900828, 0.9920999130900828, 1.0]
# 214
# [1.0, 0.9262856912648827, 0.9262856912648827, 1.0]
# 215
# [1.0, 0.8647308361335991, 0.8647308361335991, 1.0]
# 216
# [1.0, 0.9846387853362318, 0.9846387853362318, 1.0]
# 217
# [1.0, 0.9813281665924768, 0.9813281665924768, 1.0]
# 218
# [1.0, 0.9141775810563633, 0.9141775810563633, 1.0]
# 219
# [1.0, 0.9356358224264343, 0.9356358224264343, 1.0]
# 220
# [1.0, 0.9928974831853328, 0.9928974831853328, 1.0]
# 221
# [1.0, 0.9640868558200685, 0.9640868558200685, 1.0]
# 222
# [1.0, 0.9818361410469548, 0.9818361410469548, 1.0]
# 223
# [1.0, 0.9765852514995697, 0.9765852514995697, 1.0]
# 224
# [1.0, 0.9854840099250947, 0.9854840099250947, 1.0]
# 225
# [1.0, 0.9441868770624261, 0.9441868770624261, 1.0]
# 226
# [1.0, 0.9410948718322567, 0.9410948718322567, 1.0]
# 227
# [1.0, 0.9285817707294725, 0.9285817707294725, 1.0]
# 228
# [1.0, 0.9660528578195136, 0.9660528578195136, 1.0]
# 229
# [1.0, 0.9842592059082976, 0.9842592059082976, 1.0]
# 230
# [1.0, 0.9187962723003803, 0.9187962723003803, 1.0]
# 231
# [1.0, 0.9973187497156879, 0.9973187497156879, 1.0]
# 232
# [1.0, 0.9704216979480441, 0.9704216979480441, 1.0]
# 233
# [1.0, 0.9624399540212252, 0.9624399540212252, 1.0]
# 234
# [1.0, 0.9375376709433723, 0.9375376709433723, 1.0]
# 235
# [1.0, 0.996771054598217, 0.996771054598217, 1.0]
# 236
# [1.0, 0.9822815925006384, 0.9822815925006384, 1.0]
# 237
# [1.0, 0.9590978124383667, 0.9590978124383667, 1.0]
# 238
# [1.0, 0.9546771380465812, 0.9546771380465812, 1.0]
# 239
# [1.0, 0.9722740453739659, 0.9722740453739659, 1.0]
# 240
# [1.0, 0.9889139761655531, 0.9889139761655531, 1.0]
# 241
# [1.0, 0.9624348911517164, 0.9624348911517164, 1.0]
# 242
# [1.0, 0.9368159142845366, 0.9368159142845366, 1.0]
# 243
# [1.0, 0.9186712401893354, 0.9186712401893354, 1.0]
# 244
# [1.0, 0.9590354817356278, 0.9590354817356278, 1.0]
# 245
# [1.0, 0.9468677462095204, 0.9468677462095204, 1.0]
# 246
# [1.0, 0.9923821947416783, 0.9923821947416783, 1.0]
# 247
# [1.0, 0.9882741296313635, 0.9882741296313635, 1.0]
# 248
# [1.0, 0.9034430151882092, 0.9034430151882092, 1.0]
# 249
# [1.0, 0.9242883032928148, 0.9242883032928148, 1.0]
# 250
# [1.0, 0.9999319100047279, 0.9999319100047279, 1.0]
# 251
# [1.0, 0.9432984172575576, 0.9432984172575576, 1.0]
# 252
# [1.0, 0.9926676334624489, 0.9926676334624489, 1.0]
# 253
# [1.0, 0.9006504102851696, 0.9006504102851696, 1.0]
# 254
# [1.0, 0.9309801323428455, 0.9309801323428455, 1.0]
# 255
# [1.0, 0.9558983948591215, 0.9558983948591215, 1.0]
# 256
# [1.0, 0.931593799715142, 0.931593799715142, 1.0]
# 257
# [1.0, 0.9035708457464182, 0.9035708457464182, 1.0]
# 258
# [1.0, 0.9627621135411284, 0.9627621135411284, 1.0]
# 259
# [1.0, 0.9487943137897302, 0.9487943137897302, 1.0]
# 260
# [1.0, 0.9429275139708961, 0.9429275139708961, 1.0]
# 261
# [1.0, 0.9378488206369243, 0.9378488206369243, 1.0]
# 262
# [1.0, 0.9961280092124833, 0.9961280092124833, 1.0]
# 263
# [1.0, 0.8741530182057307, 0.8741530182057307, 1.0]
# 264
# [1.0, 0.9098821344369126, 0.9098821344369126, 1.0]
# 265
# [1.0, 0.8997947165756894, 0.8997947165756894, 1.0]
# 266
# [1.0, 0.9589965894181826, 0.9589965894181826, 1.0]
# 267
# [1.0, 0.8175251253963127, 0.8175251253963127, 1.0]
# 268
# [1.0, 0.9700464614465268, 0.9700464614465268, 1.0]
# 269
# [1.0, 0.9375119039619848, 0.9375119039619848, 1.0]
# 270
# [1.0, 0.9625609268320379, 0.9625609268320379, 1.0]
# 271
# [1.0, 0.9537510258696282, 0.9537510258696282, 1.0]
# 272
# [1.0, 0.9854175866426824, 0.9854175866426824, 1.0]
# 273
# [1.0, 0.9777433669107946, 0.9777433669107946, 1.0]
# 274
# [1.0, 0.9980346944220276, 0.9980346944220276, 1.0]
# 275
# [1.0, 0.9717412670941842, 0.9717412670941842, 1.0]
# 276
# [1.0, 0.9592923283120117, 0.9592923283120117, 1.0]
# 277
# [1.0, 0.9988837199177861, 0.9988837199177861, 1.0]
# 278
# [1.0, 0.9464363693323153, 0.9464363693323153, 1.0]
# 279
# [1.0, 0.9552685049233824, 0.9552685049233824, 1.0]
# 280
# [1.0, 0.9354624738776928, 0.9354624738776928, 1.0]
# 281
# [1.0, 0.877932826646116, 0.877932826646116, 1.0]
# 282
# [1.0, 0.9877106274206569, 0.9877106274206569, 1.0]
# 283
# [1.0, 0.9296262061434637, 0.9296262061434637, 1.0]
# 284
# [1.0, 0.9819314959409788, 0.9819314959409788, 1.0]
# 285
# [1.0, 0.9930753643935745, 0.9930753643935745, 1.0]
# 286
# [1.0, 0.9868490828934052, 0.9868490828934052, 1.0]
# 287
# [1.0, 0.9989974744907433, 0.9989974744907433, 1.0]
# 288
# [1.0, 0.9903983317294233, 0.9903983317294233, 1.0]
# 289
# [1.0, 0.9319979596575969, 0.9319979596575969, 1.0]
# 290
# [1.0, 0.9549170867890049, 0.9549170867890049, 1.0]
# 291
# [1.0, 0.9472051745049845, 0.9472051745049845, 1.0]
# 292
# [1.0, 0.888401169593166, 0.888401169593166, 1.0]
# 293
# [1.0, 0.9692195982050272, 0.9692195982050272, 1.0]
# 294
# [1.0, 0.9613808254146097, 0.9613808254146097, 1.0]
# 295
# [1.0, 0.9064011229443626, 0.9064011229443626, 1.0]
# 296
# [1.0, 0.9876147469515391, 0.9876147469515391, 1.0]
# 297
# [1.0, 0.9468582547537197, 0.9468582547537197, 1.0]
# 298
# [1.0, 0.9504191877660746, 0.9504191877660746, 1.0]
# 299
# [1.0, 0.9783305278002238, 0.9783305278002238, 1.0]
# 300
# [1.0, 0.8851765499255511, 0.8851765499255511, 1.0]
# 301
# [1.0, 0.934879001560768, 0.934879001560768, 1.0]
# 302
# [1.0, 0.9006139773305427, 0.9006139773305427, 1.0]
# 303
# [1.0, 0.9481971219114241, 0.9481971219114241, 1.0]
# 304
# [1.0, 0.9715068628195637, 0.9715068628195637, 1.0]
# 305
# [1.0, 0.9641014457767034, 0.9641014457767034, 1.0]
# 306
# [1.0, 0.9622748512332491, 0.9622748512332491, 1.0]
# 307
# [1.0, 0.9835203059615761, 0.9835203059615761, 1.0]
# 308
# [1.0, 0.9438119466845788, 0.9438119466845788, 1.0]
# 309
# [1.0, 0.8896140826217211, 0.8896140826217211, 1.0]
# 310
# [1.0, 0.9442903968783329, 0.9442903968783329, 1.0]
# 311
# [1.0, 0.961207884411832, 0.961207884411832, 1.0]
# 312
# [1.0, 0.9729597141275567, 0.9729597141275567, 1.0]
# 313
# [1.0, 0.9590988676060508, 0.9590988676060508, 1.0]
# 314
# [1.0, 0.9142723175782936, 0.9142723175782936, 1.0]
# 315
# [1.0, 0.9484308578932711, 0.9484308578932711, 1.0]
# 316
# [1.0, 0.9868668129657768, 0.9868668129657768, 1.0]
# 317
# [1.0, 0.9471392658740159, 0.9471392658740159, 1.0]
# 318
# [1.0, 0.8777281610243021, 0.8777281610243021, 1.0]
# 319
# [1.0, 0.9542573126098524, 0.9542573126098524, 1.0]
# 320
# [1.0, 0.9576268238126423, 0.9576268238126423, 1.0]
# 321
# [1.0, 0.920571219705249, 0.920571219705249, 1.0]
# 322
# [1.0, 0.9413681772347968, 0.9413681772347968, 1.0]
# 323
# [1.0, 0.9276414997181097, 0.9276414997181097, 1.0]
# 324
# [1.0, 0.9200366798006889, 0.9200366798006889, 1.0]
# 325
# [1.0, 0.9617779513116265, 0.9617779513116265, 1.0]
# 326
# [1.0, 0.9829078739926842, 0.9829078739926842, 1.0]
# 327
# [1.0, 0.923074445371225, 0.923074445371225, 1.0]
# 328
# [1.0, 0.9634153753717727, 0.9634153753717727, 1.0]
# 329
# [1.0, 0.9655459757140521, 0.9655459757140521, 1.0]
# 330
# [1.0, 0.9870459491497765, 0.9870459491497765, 1.0]
# 331
# [1.0, 0.947270248133251, 0.947270248133251, 1.0]
# 332
# [1.0, 0.9738127183081163, 0.9738127183081163, 1.0]
# 333
# [1.0, 0.963348946417288, 0.963348946417288, 1.0]
# 334
# [1.0, 0.9974255967260727, 0.9974255967260727, 1.0]
# 335
# [1.0, 0.9953642345787113, 0.9953642345787113, 1.0]
# 336
# [1.0, 0.9345501711086092, 0.9345501711086092, 1.0]
# 337
# [1.0, 0.9929530094135105, 0.9929530094135105, 1.0]
# 338
# [1.0, 0.86266491546116, 0.86266491546116, 1.0]
# 339
# [1.0, 0.9392783960922675, 0.9392783960922675, 1.0]
# 340
# [1.0, 0.9749056981763771, 0.9749056981763771, 1.0]
# 341
# [1.0, 0.9861608924627664, 0.9861608924627664, 1.0]
# 342
# [1.0, 0.9989299909275162, 0.9989299909275162, 1.0]
# 343
# [1.0, 0.8956396716776989, 0.8956396716776989, 1.0]
# 344
# [1.0, 0.9253947969976732, 0.9253947969976732, 1.0]
# 345
# [1.0, 0.9551279123038969, 0.9551279123038969, 1.0]
# 346
# [1.0, 0.9637890795039952, 0.9637890795039952, 1.0]
# 347
# [1.0, 0.9174662357922568, 0.9174662357922568, 1.0]
# 348
# [1.0, 0.9968971718538812, 0.9968971718538812, 1.0]
# 349
# [1.0, 0.9882046603323257, 0.9882046603323257, 1.0]
# 350
# [1.0, 0.9477595090346388, 0.9477595090346388, 1.0]
# 351
# [1.0, 0.9169315297400048, 0.9169315297400048, 1.0]
# 352
# [1.0, 0.983143852008803, 0.983143852008803, 1.0]
# 353
# [1.0, 0.9958440624555102, 0.9958440624555102, 1.0]
# 354
# [1.0, 0.995537181741587, 0.995537181741587, 1.0]
# 355
# [1.0, 0.9123708568134495, 0.9123708568134495, 1.0]
# 356
# [1.0, 0.9734017200119007, 0.9734017200119007, 1.0]
# 357
# [1.0, 0.9312732344252099, 0.9312732344252099, 1.0]
# 358
# [1.0, 0.9883338574390658, 0.9883338574390658, 1.0]
# 359
# [1.0, 0.9265786337961824, 0.9265786337961824, 1.0]
# 360
# [1.0, 0.9520065749767505, 0.9520065749767505, 1.0]
# 361
# [1.0, 0.9321102233977371, 0.9321102233977371, 1.0]
# 362
# [1.0, 0.9113990533085282, 0.9113990533085282, 1.0]
# 363
# [1.0, 0.9259547245840858, 0.9259547245840858, 1.0]
# 364
# [1.0, 0.9267426649763459, 0.9267426649763459, 1.0]
# 365
# [1.0, 0.9357748912573387, 0.9357748912573387, 1.0]
# 366
# [1.0, 0.9525543015010611, 0.9525543015010611, 1.0]
# 367
# [1.0, 0.9818274316592064, 0.9818274316592064, 1.0]
# 368
# [1.0, 0.9665498897357591, 0.9665498897357591, 1.0]
# 369
# [1.0, 0.9740605449198536, 0.9740605449198536, 1.0]
# 370
# [1.0, 0.9600037960519062, 0.9600037960519062, 1.0]
# 371
# [1.0, 0.9942528687729143, 0.9942528687729143, 1.0]
# 372
# [1.0, 0.9401396184335113, 0.9401396184335113, 1.0]
# 373
# [1.0, 0.9579171718333745, 0.9579171718333745, 1.0]
# 374
# [1.0, 0.8885215172221405, 0.8885215172221405, 1.0]
# 375
# [1.0, 0.8662483708573463, 0.8662483708573463, 1.0]
# 376
# [1.0, 0.9979070614050506, 0.9979070614050506, 1.0]
# 377
# [1.0, 0.9539485703073595, 0.9539485703073595, 1.0]
# 378
# [1.0, 0.9833829482055728, 0.9833829482055728, 1.0]
# 379
# [1.0, 0.9779268872279259, 0.9779268872279259, 1.0]
# 380
# [1.0, 0.9491322554475579, 0.9491322554475579, 1.0]
# 381
# [1.0, 0.996187848173778, 0.996187848173778, 1.0]
# 382
# [1.0, 0.9686162807936182, 0.9686162807936182, 1.0]
# 383
# [1.0, 0.9538067268620115, 0.9538067268620115, 1.0]
# 384
# [1.0, 0.9235432422136753, 0.9235432422136753, 1.0]
# 385
# [1.0, 0.9722135338531456, 0.9722135338531456, 1.0]
# 386
# [1.0, 0.9421501980527343, 0.9421501980527343, 1.0]
# 387
# [1.0, 0.9175204514082818, 0.9175204514082818, 1.0]
# 388
# [1.0, 0.9690634587022567, 0.9690634587022567, 1.0]
# 389
# [1.0, 0.9719916891313796, 0.9719916891313796, 1.0]
# 390
# [1.0, 0.9945925746333174, 0.9945925746333174, 1.0]
# 391
# [1.0, 0.9919802879196513, 0.9919802879196513, 1.0]
# 392
# [1.0, 0.9575776367071333, 0.9575776367071333, 1.0]
# 393
# [1.0, 0.9760263914650125, 0.9760263914650125, 1.0]
# 394
# [1.0, 0.9267351364634057, 0.9267351364634057, 1.0]
# 395
# [1.0, 0.9847286696035078, 0.9847286696035078, 1.0]
# 396
# [1.0, 0.9392631223077202, 0.9392631223077202, 1.0]
# 397
# [1.0, 0.9133847558086146, 0.9133847558086146, 1.0]
# 398
# [1.0, 0.996829492956446, 0.996829492956446, 1.0]
# 399
# [1.0, 0.9244663092671246, 0.9244663092671246, 1.0]
# 400
# [1.0, 0.9185214486460045, 0.9185214486460045, 1.0]
# 401
# [1.0, 0.9813521706412683, 0.9813521706412683, 1.0]
# 402
# [1.0, 0.8658624953587941, 0.8658624953587941, 1.0]
# 403
# [1.0, 0.9440889913513865, 0.9440889913513865, 1.0]
# 404
# [1.0, 0.9930030122677643, 0.9930030122677643, 1.0]
# 405
# [1.0, 0.9671044105239961, 0.9671044105239961, 1.0]
# 406
# [1.0, 0.9597389183721897, 0.9597389183721897, 1.0]
# 407
# [1.0, 0.9729122787452676, 0.9729122787452676, 1.0]
# 408
# [1.0, 0.9410387074997815, 0.9410387074997815, 1.0]
# 409
# [1.0, 0.9944352206871679, 0.9944352206871679, 1.0]
# 410
# [1.0, 0.887899493444794, 0.887899493444794, 1.0]
# 411
# [1.0, 0.9661856282929526, 0.9661856282929526, 1.0]
# 412
# [1.0, 0.9813802346091536, 0.9813802346091536, 1.0]
# 413
# [1.0, 0.9745335512940002, 0.9745335512940002, 1.0]
# 414
# [1.0, 0.9847124794780748, 0.9847124794780748, 1.0]
# 415
# [1.0, 0.9836944796449306, 0.9836944796449306, 1.0]
# 416
# [1.0, 0.9406567599898534, 0.9406567599898534, 1.0]
# 417
# [1.0, 0.8761781920630207, 0.8761781920630207, 1.0]
# 418
# [1.0, 0.9861389444563885, 0.9861389444563885, 1.0]
# 419
# [1.0, 0.9945165362761273, 0.9945165362761273, 1.0]
# 420
# [1.0, 0.97258148747839, 0.97258148747839, 1.0]
# 421
# [1.0, 0.996497770660982, 0.996497770660982, 1.0]
# 422
# [1.0, 0.9748211183863671, 0.9748211183863671, 1.0]
# 423
# [1.0, 0.920633186372575, 0.920633186372575, 1.0]
# 424
# [1.0, 0.8615931381734494, 0.8615931381734494, 1.0]
# 425
# [1.0, 0.9005355968845312, 0.9005355968845312, 1.0]
# 426
# [1.0, 0.9640957874050938, 0.9640957874050938, 1.0]
# 427
# [1.0, 0.9894332601332864, 0.9894332601332864, 1.0]
# 428
# [1.0, 0.9826722729954452, 0.9826722729954452, 1.0]
# 429
# [1.0, 0.9637403952400201, 0.9637403952400201, 1.0]
# 430
# [1.0, 0.9589190318760065, 0.9589190318760065, 1.0]
# 431
# [1.0, 0.9757153663666389, 0.9757153663666389, 1.0]
# 432
# [1.0, 0.977195441687805, 0.977195441687805, 1.0]
# 433
# [1.0, 0.94158019661899, 0.94158019661899, 1.0]
# 434
# [1.0, 0.9553268641482688, 0.9553268641482688, 1.0]
# 435
# [1.0, 0.9273663204544987, 0.9273663204544987, 1.0]
# 436
# [1.0, 0.9918275040294084, 0.9918275040294084, 1.0]
# 437
# [1.0, 0.9979648117573015, 0.9979648117573015, 1.0]
# 438
# [1.0, 0.9698958528402288, 0.9698958528402288, 1.0]
# 439
# [1.0, 0.9163831989817389, 0.9163831989817389, 1.0]
# 440
# [1.0, 0.9745935319995125, 0.9745935319995125, 1.0]
# 441
# [1.0, 0.9778520295475179, 0.9778520295475179, 1.0]
# 442
# [1.0, 0.9672932623211141, 0.9672932623211141, 1.0]
# 443
# [1.0, 0.9376324727788667, 0.9376324727788667, 1.0]
# 444
# [nan, nan, nan, 1.0]
# 445
# [1.0, 0.9581679953714043, 0.9581679953714043, 1.0]
# 446
# [1.0, 0.9997772304384214, 0.9997772304384214, 1.0]
# 447
# [1.0, 0.979597814951021, 0.979597814951021, 1.0]
# 448
# [1.0, 0.9950652098966823, 0.9950652098966823, 1.0]
# 449
# [1.0, 0.9528610292542513, 0.9528610292542513, 1.0]
# 450
# [1.0, 0.9668696593247446, 0.9668696593247446, 1.0]
# 451
# [1.0, 0.9834300872929898, 0.9834300872929898, 1.0]
# 452
# [1.0, 0.9992680978425726, 0.9992680978425726, 1.0]
# 453
# [1.0, 0.9946277983023919, 0.9946277983023919, 1.0]
# 454
# [1.0, 0.9972154127250492, 0.9972154127250492, 1.0]
# 455
# [1.0, 0.9460231018783133, 0.9460231018783133, 1.0]
# 456
# [1.0, 0.9854417221847084, 0.9854417221847084, 1.0]
# 457
# [1.0, 0.9793561721024148, 0.9793561721024148, 1.0]
# 458
# [1.0, 0.8926574506159596, 0.8926574506159596, 1.0]
# 459
# [1.0, 0.9812632730964383, 0.9812632730964383, 1.0]
# 460
# [1.0, 0.9612745927741045, 0.9612745927741045, 1.0]
# 461
# [1.0, 0.9981624940476195, 0.9981624940476195, 1.0]
# 462
# [1.0, 0.9330654839164296, 0.9330654839164296, 1.0]
# 463
# [1.0, 0.9813293943801349, 0.9813293943801349, 1.0]
# 464
# [1.0, 0.9478665694341821, 0.9478665694341821, 1.0]
# 465
# [1.0, 0.9788618795950679, 0.9788618795950679, 1.0]
# 466
# [1.0, 0.9862179008236288, 0.9862179008236288, 1.0]
# 467
# [1.0, 0.9275831668437564, 0.9275831668437564, 1.0]
# 468
# [1.0, 0.9536343770088573, 0.9536343770088573, 1.0]
# 469
# [1.0, 0.9420982728642808, 0.9420982728642808, 1.0]
# 470
# [1.0, 0.9091598634394381, 0.9091598634394381, 1.0]
# 471
# [1.0, 0.9156899350185161, 0.9156899350185161, 1.0]
# 472
# [1.0, 0.9755656176475449, 0.9755656176475449, 1.0]
# 473
# [1.0, 0.9511605200431651, 0.9511605200431651, 1.0]
# 474
# [1.0, 0.8849783030541257, 0.8849783030541257, 1.0]
# 475
# [1.0, 0.9402150095694791, 0.9402150095694791, 1.0]
# 476
# [1.0, 0.9320731461294682, 0.9320731461294682, 1.0]
# 477
# [1.0, 0.969952621262794, 0.969952621262794, 1.0]
# 478
# [1.0, 0.9473003626359213, 0.9473003626359213, 1.0]
# 479
# [1.0, 0.9465034873813413, 0.9465034873813413, 1.0]
# 480
# [1.0, 0.9484374574930878, 0.9484374574930878, 1.0]
# 481
# [1.0, 0.9721182804473715, 0.9721182804473715, 1.0]
# 482
# [1.0, 0.9666564088434864, 0.9666564088434864, 1.0]
# 483
# [1.0, 0.9645871582471905, 0.9645871582471905, 1.0]
# 484
# [1.0, 0.9245313174020376, 0.9245313174020376, 1.0]
# 485
# [1.0, 0.9701472029858635, 0.9701472029858635, 1.0]
# 486
# [1.0, 0.900775321438639, 0.900775321438639, 1.0]
# 487
# [1.0, 0.976951193751526, 0.976951193751526, 1.0]
# 488
# [1.0, 0.9821901964601221, 0.9821901964601221, 1.0]
# 489
# [1.0, 0.9516201648101362, 0.9516201648101362, 1.0]
# 490
# [1.0, 0.9920963848636475, 0.9920963848636475, 1.0]
# 491
# [1.0, 0.9555289663361767, 0.9555289663361767, 1.0]
# 492
# [1.0, 0.939003113939812, 0.939003113939812, 1.0]
# 493
# [1.0, 0.9864951952256649, 0.9864951952256649, 1.0]
# 494
# [1.0, 0.9574173360236857, 0.9574173360236857, 1.0]
# 495
# [1.0, 0.9699419136199249, 0.9699419136199249, 1.0]
# 496
# [1.0, 0.9344610734294347, 0.9344610734294347, 1.0]
# 497
# [1.0, 0.9916772082770968, 0.9916772082770968, 1.0]
# 498
# [1.0, 0.9357019988544957, 0.9357019988544957, 1.0]
# 499
# [1.0, 0.9329792621410276, 0.9329792621410276, 1.0]
# 500
# [1.0, 0.9210925636639481, 0.9210925636639481, 1.0]
# 501
# [1.0, 0.9749344766803314, 0.9749344766803314, 1.0]
# 502
# [1.0, 0.9498663904761836, 0.9498663904761836, 1.0]
# 503
# [1.0, 0.8819035139000991, 0.8819035139000991, 1.0]
# 504
# [1.0, 0.9608136419284201, 0.9608136419284201, 1.0]
# 505
# [1.0, 0.9464049969341694, 0.9464049969341694, 1.0]
# 506
# [1.0, 0.9208144429943235, 0.9208144429943235, 1.0]
# 507
# [1.0, 0.9695950205088378, 0.9695950205088378, 1.0]
# 508
# [1.0, 0.9460091482023637, 0.9460091482023637, 1.0]
# 509
# [1.0, 0.959447658259053, 0.959447658259053, 1.0]
# 510
# [1.0, 0.9429574094083638, 0.9429574094083638, 1.0]
# 511
# [1.0, 0.9935963678183675, 0.9935963678183675, 1.0]
# 512
# [1.0, 0.9404464121865123, 0.9404464121865123, 1.0]
# 513
# [1.0, 0.9819727644729216, 0.9819727644729216, 1.0]
# 514
# [1.0, 0.9646751867442916, 0.9646751867442916, 1.0]
# 515
# [1.0, 0.9895959261547116, 0.9895959261547116, 1.0]
# 516
# [1.0, 0.9568980561813767, 0.9568980561813767, 1.0]
# 517
# [1.0, 0.9014371701868472, 0.9014371701868472, 1.0]
# 518
# [1.0, 0.9649737343558569, 0.9649737343558569, 1.0]
# 519
# [1.0, 0.975309700479335, 0.975309700479335, 1.0]
# 520
# [1.0, 0.9398358402100905, 0.9398358402100905, 1.0]
# 521
# [1.0, 0.965633014902047, 0.965633014902047, 1.0]
# 522
# [1.0, 0.9611287519924139, 0.9611287519924139, 1.0]
# 523
# [1.0, 0.9775377489993003, 0.9775377489993003, 1.0]
# 524
# [1.0, 0.960232408046545, 0.960232408046545, 1.0]
# 525
# [1.0, 0.9587929300347564, 0.9587929300347564, 1.0]
# 526
# [1.0, 0.9846512523841948, 0.9846512523841948, 1.0]
# 527
# [1.0, 0.938028195435051, 0.938028195435051, 1.0]
# 528
# [1.0, 0.9950983538903476, 0.9950983538903476, 1.0]
# 529
# [1.0, 0.9863587106300562, 0.9863587106300562, 1.0]
# 530
# [1.0, 0.9983309610400941, 0.9983309610400941, 1.0]
# 531
# [1.0, 0.9561613675247579, 0.9561613675247579, 1.0]
# 532
# [1.0, 0.926002737567976, 0.926002737567976, 1.0]
# 533
# [1.0, 0.9021547084342345, 0.9021547084342345, 1.0]
# 534
# [1.0, 0.9142795326026696, 0.9142795326026696, 1.0]
# 535
# [1.0, 0.9309843107208462, 0.9309843107208462, 1.0]
# 536
# [1.0, 0.9545149814676032, 0.9545149814676032, 1.0]
# 537
# [1.0, 0.9598069163586634, 0.9598069163586634, 1.0]
# 538
# [1.0, 0.8994911914440598, 0.8994911914440598, 1.0]
# 539
# [1.0, 0.8897274162110266, 0.8897274162110266, 1.0]
# 540
# [1.0, 0.9291164866830608, 0.9291164866830608, 1.0]
# 541
# [1.0, 0.9718352246855824, 0.9718352246855824, 1.0]
# 542
# [1.0, 0.9041120630544576, 0.9041120630544576, 1.0]
# 543
# [1.0, 0.9099541943597456, 0.9099541943597456, 1.0]
# 544
# [1.0, 0.986589633496141, 0.986589633496141, 1.0]
# 545
# [1.0, 0.9136090461817812, 0.9136090461817812, 1.0]
# 546
# [1.0, 0.9794654501683118, 0.9794654501683118, 1.0]
# 547
# [1.0, 0.9463269054767798, 0.9463269054767798, 1.0]
# 548
# [1.0, 0.9758418573081464, 0.9758418573081464, 1.0]
# 549
# [1.0, 0.962667805470406, 0.962667805470406, 1.0]
# 550
# [1.0, 0.8892869903524145, 0.8892869903524145, 1.0]
# 551
# [1.0, 0.9765186636637867, 0.9765186636637867, 1.0]
# 552
# [1.0, 0.9677658054434596, 0.9677658054434596, 1.0]
# 553
# [1.0, 0.9781684282354962, 0.9781684282354962, 1.0]
# 554
# [1.0, 0.897479326056971, 0.897479326056971, 1.0]
# 555
# [1.0, 0.9212680093015121, 0.9212680093015121, 1.0]
# 556
# [1.0, 0.895399944759185, 0.895399944759185, 1.0]
# 557
# [1.0, 0.9527729250242485, 0.9527729250242485, 1.0]
# 558
# [1.0, 0.9532680225582567, 0.9532680225582567, 1.0]
# 559
# [1.0, 0.9695978370481529, 0.9695978370481529, 1.0]
# 560
# [1.0, 0.9163432768039582, 0.9163432768039582, 1.0]
# 561
# [1.0, 0.9591760940392337, 0.9591760940392337, 1.0]
# 562
# [1.0, 0.9538971443438083, 0.9538971443438083, 1.0]
# 563
# [1.0, 0.9251579967910007, 0.9251579967910007, 1.0]
# 564
# [1.0, 0.9532873997856176, 0.9532873997856176, 1.0]
# 565
# [nan, nan, nan, 1.0]
# 566
# [nan, nan, nan, 1.0]
# 567
# [1.0, 0.9559469033367244, 0.9559469033367244, 1.0]
# 568
# [1.0, 0.994528935899968, 0.994528935899968, 1.0]
# 569
# [1.0, 0.9379950136997174, 0.9379950136997174, 1.0]
# 570
# [1.0, 0.9896022594524754, 0.9896022594524754, 1.0]
# 571
# [1.0, 0.9870879443616128, 0.9870879443616128, 1.0]
# 572
# [1.0, 0.9939050894183062, 0.9939050894183062, 1.0]
# 573
# [1.0, 0.9307196742977935, 0.9307196742977935, 1.0]
# 574
# [1.0, 0.9634493427823884, 0.9634493427823884, 1.0]
# 575
# [1.0, 0.9947571254915492, 0.9947571254915492, 1.0]
# 576
# [1.0, 0.9354464832070146, 0.9354464832070146, 1.0]
# 577
# [1.0, 0.9054657363376742, 0.9054657363376742, 1.0]
# 578
# [1.0, 0.9488637573113371, 0.9488637573113371, 1.0]
# 579
# [1.0, 0.9529440271275654, 0.9529440271275654, 1.0]
# 580
# [1.0, 0.972248726485315, 0.972248726485315, 1.0]
# 581
# [1.0, 0.977199327325018, 0.977199327325018, 1.0]
# 582
# [1.0, 0.973722738534832, 0.973722738534832, 1.0]
# 583
# [1.0, 0.9020833052642937, 0.9020833052642937, 1.0]
# 584
# [1.0, 0.9925566784295552, 0.9925566784295552, 1.0]
# 585
# [1.0, 0.9803099214079128, 0.9803099214079128, 1.0]
# 586
# [1.0, 0.95288321354853, 0.95288321354853, 1.0]
# 587
# [1.0, 0.968913471194663, 0.968913471194663, 1.0]
# 588
# [1.0, 0.9879583516328974, 0.9879583516328974, 1.0]
# 589
# [1.0, 0.9767381577767494, 0.9767381577767494, 1.0]
# 590
# [1.0, 0.9399655992077839, 0.9399655992077839, 1.0]
# 591
# [1.0, 0.908999046588422, 0.908999046588422, 1.0]
# 592
# [1.0, 0.9366775269641426, 0.9366775269641426, 1.0]
# 593
# [1.0, 0.9622503723894559, 0.9622503723894559, 1.0]
# 594
# [1.0, 0.9216625710896194, 0.9216625710896194, 1.0]
# 595
# [1.0, 0.9774862014372344, 0.9774862014372344, 1.0]
# 596
# [1.0, 0.8827173530853086, 0.8827173530853086, 1.0]
# 597
# [1.0, 0.9738515656986456, 0.9738515656986456, 1.0]
# 598
# [1.0, 0.9254868057400332, 0.9254868057400332, 1.0]
# 599
# [1.0, 0.982709608723659, 0.982709608723659, 1.0]
# 600
# [1.0, 0.9886606936619265, 0.9886606936619265, 1.0]
# 601
# [1.0, 0.9601139812953305, 0.9601139812953305, 1.0]
# 602
# [1.0, 0.9128559873920061, 0.9128559873920061, 1.0]
# 603
# [1.0, 0.9364745205349233, 0.9364745205349233, 1.0]
# 604
# [1.0, 0.9626635541097703, 0.9626635541097703, 1.0]
# 605
# [1.0, 0.9054331747589262, 0.9054331747589262, 1.0]
# 606
# [1.0, 0.9753515871117671, 0.9753515871117671, 1.0]
# 607
# [1.0, 0.9591405189674052, 0.9591405189674052, 1.0]
# 608
# [1.0, 0.9979125094378464, 0.9979125094378464, 1.0]
# 609
# [1.0, 0.9465413464065124, 0.9465413464065124, 1.0]
# 610
# [1.0, 0.9678738119946845, 0.9678738119946845, 1.0]
# 611
# [1.0, 0.968480625746801, 0.968480625746801, 1.0]
# 612
# [1.0, 0.932442632978639, 0.932442632978639, 1.0]
# 613
# [1.0, 0.918952042984364, 0.918952042984364, 1.0]
# 614
# [1.0, 0.952573121315894, 0.952573121315894, 1.0]
# 615
# [1.0, 0.9721315956940688, 0.9721315956940688, 1.0]
# 616
# [1.0, 0.8887765290207255, 0.8887765290207255, 1.0]
# 617
# [1.0, 0.9698580630832612, 0.9698580630832612, 1.0]
# 618
# [1.0, 0.8815140340225591, 0.8815140340225591, 1.0]
# 619
# [1.0, 0.958739471864278, 0.958739471864278, 1.0]
# 620
# [1.0, 0.9911383376234062, 0.9911383376234062, 1.0]
# 621
# [1.0, 0.960395965146018, 0.960395965146018, 1.0]
# 622
# [1.0, 0.9674431752764772, 0.9674431752764772, 1.0]
# 623
# [1.0, 0.9750356906689939, 0.9750356906689939, 1.0]
# 624
# [1.0, 0.9629955229707395, 0.9629955229707395, 1.0]
# 625
# [1.0, 0.94783836937003, 0.94783836937003, 1.0]
# 626
# [1.0, 0.9571019511427054, 0.9571019511427054, 1.0]
# 627
# [1.0, 0.9730712533504079, 0.9730712533504079, 1.0]
# 628
# [1.0, 0.972671405905472, 0.972671405905472, 1.0]
# 629
# [1.0, 0.9687168210249556, 0.9687168210249556, 1.0]
# 630
# [1.0, 0.9310151874147017, 0.9310151874147017, 1.0]
# 631
# [1.0, 0.9459596295084559, 0.9459596295084559, 1.0]
# 632
# [1.0, 0.9978389883253018, 0.9978389883253018, 1.0]
# 633
# [1.0, 0.9946905294861443, 0.9946905294861443, 1.0]
# 634
# [1.0, 0.93109779758625, 0.93109779758625, 1.0]
# 635
# [1.0, 0.9209735801528455, 0.9209735801528455, 1.0]
# 636
# [1.0, 0.9442383984359063, 0.9442383984359063, 1.0]
# 637
# [1.0, 0.9727429205521133, 0.9727429205521133, 1.0]
# 638
# [1.0, 0.9040251613198453, 0.9040251613198453, 1.0]
# 639
# [1.0, 0.946509075041212, 0.946509075041212, 1.0]
# 640
# [1.0, 0.9701788876868715, 0.9701788876868715, 1.0]
# 641
# [1.0, 0.9129013846292486, 0.9129013846292486, 1.0]
# 642
# [1.0, 0.8864921198400328, 0.8864921198400328, 1.0]
# 643
# [1.0, 0.9161022469710249, 0.9161022469710249, 1.0]
# 644
# [1.0, 0.9415632250573054, 0.9415632250573054, 1.0]
# 645
# [1.0, 0.9288394965855886, 0.9288394965855886, 1.0]
# 646
# [1.0, 0.998229405312388, 0.998229405312388, 1.0]
# 647
# [1.0, 0.9955569230504484, 0.9955569230504484, 1.0]
# 648
# [1.0, 0.9612166175279522, 0.9612166175279522, 1.0]
# 649
# [1.0, 0.993113215625546, 0.993113215625546, 1.0]
# 650
# [1.0, 0.9981472605615496, 0.9981472605615496, 1.0]
# 651
# [1.0, 0.9667292197974918, 0.9667292197974918, 1.0]
# 652
# [1.0, 0.9991959639724691, 0.9991959639724691, 1.0]
# 653
# [1.0, 0.9756511987969132, 0.9756511987969132, 1.0]
# 654
# [1.0, 0.9277159882336218, 0.9277159882336218, 1.0]
# 655
# [1.0, 0.9662879781147499, 0.9662879781147499, 1.0]
# 656
# [1.0, 0.9431977063840844, 0.9431977063840844, 1.0]
# 657
# [1.0, 0.9141003529566895, 0.9141003529566895, 1.0]
# 658
# [1.0, 0.8952105341862797, 0.8952105341862797, 1.0]
# 659
# [1.0, 0.9628032864841847, 0.9628032864841847, 1.0]
# 660
# [1.0, 0.9615614747829823, 0.9615614747829823, 1.0]
# 661
# [1.0, 0.9629260675051874, 0.9629260675051874, 1.0]
# 662
# [1.0, 0.9093119463844268, 0.9093119463844268, 1.0]
# 663
# [1.0, 0.8712801465576604, 0.8712801465576604, 1.0]
# 664
# [1.0, 0.9002607056911647, 0.9002607056911647, 1.0]
# 665
# [1.0, 0.9764332758947506, 0.9764332758947506, 1.0]
# 666
# [1.0, 0.929737096617094, 0.929737096617094, 1.0]
# 667
# [1.0, 0.9206613523497094, 0.9206613523497094, 1.0]
# 668
# [1.0, 0.9726410005350089, 0.9726410005350089, 1.0]
# 669
# [1.0, 0.9529456523032107, 0.9529456523032107, 1.0]
# 670
# [1.0, 0.9730138554694587, 0.9730138554694587, 1.0]
# 671
# [1.0, 0.9959701542887522, 0.9959701542887522, 1.0]
# 672
# [1.0, 0.9440925008519336, 0.9440925008519336, 1.0]
# 673
# [1.0, 0.9974650294282477, 0.9974650294282477, 1.0]
# 674
# [1.0, 0.9515374949264718, 0.9515374949264718, 1.0]
# 675
# [1.0, 0.9532956555595824, 0.9532956555595824, 1.0]
# 676
# [1.0, 0.9641443972204047, 0.9641443972204047, 1.0]
# 677
# [1.0, 0.9837875332453406, 0.9837875332453406, 1.0]
# 678
# [nan, nan, nan, 1.0]
# 679
# [1.0, 0.9801461551574876, 0.9801461551574876, 1.0]
# 680
# [1.0, 0.977874949747636, 0.977874949747636, 1.0]
# 681
# [1.0, 0.9469093183969054, 0.9469093183969054, 1.0]
# 682
# [1.0, 0.993913612918253, 0.993913612918253, 1.0]
# 683
# [1.0, 0.9923648005955699, 0.9923648005955699, 1.0]
# 684
# [1.0, 0.9548943128435813, 0.9548943128435813, 1.0]
# 685
# [1.0, 0.9713549544248197, 0.9713549544248197, 1.0]
# 686
# [1.0, 0.9438225079402185, 0.9438225079402185, 1.0]
# 687
# [1.0, 0.9793229122335431, 0.9793229122335431, 1.0]
# 688
# [1.0, 0.9399286010686179, 0.9399286010686179, 1.0]
# 689
# [1.0, 0.9891641529090597, 0.9891641529090597, 1.0]
# 690
# [1.0, 0.9456554524366231, 0.9456554524366231, 1.0]
# 691
# [1.0, 0.9631019312695825, 0.9631019312695825, 1.0]
# 692
# [1.0, 0.9273261969703679, 0.9273261969703679, 1.0]
# 693
# [1.0, 0.9330316830153558, 0.9330316830153558, 1.0]
# 694
# [1.0, 0.9573190661428552, 0.9573190661428552, 1.0]
# 695
# [1.0, 0.8689662866354148, 0.8689662866354148, 1.0]
# 696
# [1.0, 0.9568751812053954, 0.9568751812053954, 1.0]
# 697
# [1.0, 0.9919894533466783, 0.9919894533466783, 1.0]
# 698
# [1.0, 0.969954643413664, 0.969954643413664, 1.0]
# 699
# [1.0, 0.9792105969267775, 0.9792105969267775, 1.0]
# 700
# [1.0, 0.9976566613045524, 0.9976566613045524, 1.0]
# 701
# [1.0, 0.9778103840832902, 0.9778103840832902, 1.0]
# 702
# [1.0, 0.9526265147037246, 0.9526265147037246, 1.0]
# 703
# [1.0, 0.9163543390991592, 0.9163543390991592, 1.0]
# 704
# [1.0, 0.938645798920488, 0.938645798920488, 1.0]
# 705
# [1.0, 0.9430629004535198, 0.9430629004535198, 1.0]
# 706
# [1.0, 0.883431971984393, 0.883431971984393, 1.0]
# 707
# [1.0, 0.9226593728034084, 0.9226593728034084, 1.0]
# 708
# [1.0, 0.9489568092303761, 0.9489568092303761, 1.0]
# 709
# [1.0, 0.9657820942362004, 0.9657820942362004, 1.0]
# 710
# [1.0, 0.9371536418634537, 0.9371536418634537, 1.0]
# 711
# [1.0, 0.9668481243687083, 0.9668481243687083, 1.0]
# 712
# [1.0, 0.9019302239290483, 0.9019302239290483, 1.0]
# 713
# [1.0, 0.959303009950479, 0.959303009950479, 1.0]
# 714
# [1.0, 0.8691560787178874, 0.8691560787178874, 1.0]
# 715
# [1.0, 0.9431504639028371, 0.9431504639028371, 1.0]
# 716
# [1.0, 0.9334027205113634, 0.9334027205113634, 1.0]
# 717
# [1.0, 0.9809334123299974, 0.9809334123299974, 1.0]
# 718
# [1.0, 0.9756362147570803, 0.9756362147570803, 1.0]
# 719
# [1.0, 0.9571057002030708, 0.9571057002030708, 1.0]
# 720
# [1.0, 0.8950342212371247, 0.8950342212371247, 1.0]
# 721
# [1.0, 0.9338984066741027, 0.9338984066741027, 1.0]
# 722
# [1.0, 0.9831244454511227, 0.9831244454511227, 1.0]
# 723
# [1.0, 0.9297007258963911, 0.9297007258963911, 1.0]
# 724
# [1.0, 0.9142384094643137, 0.9142384094643137, 1.0]
# 725
# [1.0, 0.9381264109865093, 0.9381264109865093, 1.0]
# 726
# [1.0, 0.9924905208779772, 0.9924905208779772, 1.0]
# 727
# [1.0, 0.9670806699347249, 0.9670806699347249, 1.0]
# 728
# [1.0, 0.9578531695885821, 0.9578531695885821, 1.0]
# 729
# [1.0, 0.9683756035907571, 0.9683756035907571, 1.0]
# 730
# [1.0, 0.9516923746698933, 0.9516923746698933, 1.0]
# 731
# [1.0, 0.9818892551193994, 0.9818892551193994, 1.0]
# 732
# [1.0, 0.9565455839011285, 0.9565455839011285, 1.0]
# 733
# [1.0, 0.9944312667217149, 0.9944312667217149, 1.0]
# 734
# [1.0, 0.9964543011606225, 0.9964543011606225, 1.0]
# 735
# [1.0, 0.9797235631636774, 0.9797235631636774, 1.0]
# 736
# [1.0, 0.9543574334055537, 0.9543574334055537, 1.0]
# 737
# [1.0, 0.9955146425750668, 0.9955146425750668, 1.0]
# 738
# [1.0, 0.9631314380529589, 0.9631314380529589, 1.0]
# 739
# [1.0, 0.9715157936278048, 0.9715157936278048, 1.0]
# 740
# [1.0, 0.9362050634784422, 0.9362050634784422, 1.0]
# 741
# [1.0, 0.9785084498606044, 0.9785084498606044, 1.0]
# 742
# [1.0, 0.9724842674830596, 0.9724842674830596, 1.0]
# 743
# [1.0, 0.8839844334234304, 0.8839844334234304, 1.0]
# 744
# [1.0, 0.9171530488683572, 0.9171530488683572, 1.0]
# 745
# [1.0, 0.9733601632464352, 0.9733601632464352, 1.0]
# 746
# [1.0, 0.9117174820452459, 0.9117174820452459, 1.0]
# 747
# [1.0, 0.9814430743193491, 0.9814430743193491, 1.0]
# 748
# [nan, nan, nan, 1.0]
# 749
# [1.0, 0.959251624156752, 0.959251624156752, 1.0]
# 750
# [nan, nan, nan, 1.0]
# 751
# [1.0, 0.982947114776801, 0.982947114776801, 1.0]
# 752
# [1.0, 0.9515650490130618, 0.9515650490130618, 1.0]
# 753
# [1.0, 0.9804421907054973, 0.9804421907054973, 1.0]
# 754
# [1.0, 0.9791175964988678, 0.9791175964988678, 1.0]
# 755
# [1.0, 0.9052674147359299, 0.9052674147359299, 1.0]
# 756
# [1.0, 0.9643354251921489, 0.9643354251921489, 1.0]
# 757
# [1.0, 0.9894995482014349, 0.9894995482014349, 1.0]
# 758
# [1.0, 0.9182207616557251, 0.9182207616557251, 1.0]
# 759
# [1.0, 0.964854982337991, 0.964854982337991, 1.0]
# 760
# [1.0, 0.9242351397985469, 0.9242351397985469, 1.0]
# 761
# [1.0, 0.9817522535875618, 0.9817522535875618, 1.0]
# 762
# [1.0, 0.9442503461381861, 0.9442503461381861, 1.0]
# 763
# [1.0, 0.943125136696622, 0.943125136696622, 1.0]
# 764
# [1.0, 0.9961225824984047, 0.9961225824984047, 1.0]
# 765
# [1.0, 0.9947981292997582, 0.9947981292997582, 1.0]
# 766
# [1.0, 0.9900427986621325, 0.9900427986621325, 1.0]
# 767
# [1.0, 0.985982778828462, 0.985982778828462, 1.0]
